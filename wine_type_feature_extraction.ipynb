# %%
wine_list = ['Pinot Gris', 
 'Riesling',
 'Pinot Noir',
 'Cabernet Sauvignon',
 'Chardonnay',
 'Meritage',
 'Red Blend',
 'Merlot',
 'Chenin Blanc',
 'Sauvignon Blanc',
 'Malbec',
 'Cabernet Franc',
 'Bordeaux-style Red Blend',
 'Petite Sirah',
 'Zinfandel',
 'Albariño',
 'Viognier',
 'Grenache Blanc',
 'Syrah',
 'Rhône-style Red Blend',
 'G-S-M',
 'Fumé Blanc',
 'Gewürztraminer',
 'Sangiovese',
 'Cabernet Sauvignon-Syrah',
 'Vignoles',
 'White Blend',
 'Rosé',
 'Sparkling Blend',
 'Tempranillo',
 'Pinot Blanc',
 'Verdelho',
 'Grenache',
 'Marsanne',
 'Syrah-Grenache',
 'Grüner Veltliner',
 'Pinot Grigio',
 'Roussanne',
 "Nero d'Avola",
 'Muscat Blanc à Petits Grains',
 'Petit Verdot',
 'Charbono',
 'Rhône-style White Blend',
 'Mourvèdre',
 'Pinot Meunier',
 'Cabernet Sauvignon-Sangiovese',
 'Port',
 'Muskat Ottonel',
 'Claret',
 'Syrah-Viognier',
 'Marsanne-Roussanne',
 'Barbera',
 'Carmenère',
 'Vermentino',
 'Muscat',
 'Teroldego',
 'Moscato',
 'Traminette',
 'Chambourcin',
 'Sémillon',
 'Marsanne-Viognier',
 'Touriga Nacional',
 'Syrah-Cabernet Sauvignon',
 'Semillon-Sauvignon Blanc',
 'Garnacha',
 'Grenache-Syrah',
 'Seyval Blanc',
 'Muscat Canelli',
 'Dolcetto',
 'Sauvignon Blanc-Semillon',
 'Bordeaux-style White Blend',
 'Merlot-Cabernet Franc',
 'Syrah-Petite Sirah',
 'Primitivo',
 'Cabernet Blend',
 'Gamay Noir',
 'Vidal Blanc',
 'Gewürztraminer-Riesling',
 'Lemberger',
 'Nebbiolo',
 'Blanc du Bois',
 'Shiraz',
 'Roussanne-Viognier',
 'Colombard',
 'Auxerrois',
 'Muskat',
 'Cabernet Franc-Merlot',
 'Tannat',
 'Malvasia',
 'Pinotage',
 'Falanghina',
 'Grenache-Carignan',
 'Champagne Blend',
 'Tocai Friulano',
 'Chardonnay-Semillon',
 'Norton',
 'Montepulciano',
 'Graciano',
 'Cinsault',
 'Carignan',
 'Symphony',
 'Black Muscat',
 'Johannisberg Riesling',
 'Arneis',
 'Valdiguié',
 'Syrah-Mourvèdre',
 'Blaufränkisch',
 'Mondeuse',
 'Cabernet Merlot',
 'Petite Verdot',
 'Merlot-Malbec',
 'Mourvèdre-Syrah',
 'Clairette',
 'Malbec-Syrah',
 'Diamond',
 'Monastrell',
 'Scheurebe',
 'Aglianico',
 'Tempranillo Blend',
 'Petit Manseng',
 'Siegerrebe',
 'Trousseau Gris',
 'Cabernet Sauvignon-Merlot',
 'Grenache Blend',
 'Sagrantino',
 'Merlot-Cabernet Sauvignon',
 'Greco',
 'Aligoté',
 'Sangiovese Cabernet',
 'Muscat Blanc',
 'Viognier-Roussanne',
 'Rosato',
 'Cabernet Sauvignon-Cabernet Franc',
 'Baco Noir',
 'Barbera-Nebbiolo',
 'Piquepoul Blanc',
 'Chenin Blanc-Viognier',
 'Orange Muscat',
 'Rkatsiteli',
 'Carignane',
 'Counoise',
 'Sherry',
 'Debit',
 'Grenache-Mourvèdre',
 'Pinot-Chardonnay',
 'Syrah-Tempranillo',
 'Cabernet Sauvignon-Barbera',
 'Merlot-Cabernet',
 'Refosco',
 'Sangiovese-Cabernet Sauvignon',
 'Viognier-Gewürztraminer',
 'Müller-Thurgau',
 'Vidal',
 'Chardonnay-Viognier',
 'Lagrein',
 'Mataro',
 'Cortese',
 'Ugni Blanc',
 'Semillon-Chardonnay',
 'Fiano',
 'Trebbiano',
 'Picpoul',
 'Tempranillo-Garnacha',
 'Palomino',
 'Touriga',
 'Madeleine Angevine',
 'Alvarelhão',
 'Malbec-Merlot',
 'Viognier-Chardonnay',
 'Pinot Blanc-Pinot Noir',
 'Muscat Hamburg',
 'Sauvignon Blanc-Chenin Blanc',
 'Pinot Gris-Gewürztraminer',
 'Sauvignon Musqué',
 'Ribolla Gialla',
 'Roussanne-Marsanne',
 'Sangiovese-Syrah',
 'Mission',
 'Marquette',
 'Malbec-Tannat',
 'Tempranillo-Cabernet Sauvignon',
 'Cabernet Sauvignon-Carmenère',
 'Malvasia Bianca',
 'Negrette',
 'Torrontés',
 'Cabernet-Syrah',
 'Garnacha Blanca',
 'Alicante Bouschet',
 'Syrah-Cabernet Franc',
 'Verdejo',
 'Syrah-Merlot',
 'Pinot Auxerrois',
 'Cabernet Sauvignon-Shiraz',
 'Abouriou',
 'Pinot Noir-Syrah',
 'Syrah-Petit Verdot',
 'Souzao',
 'White Port',
 'Malbec-Cabernet Sauvignon',
 'White Riesling',
 'Zweigelt',
 'Riesling-Chardonnay',
 'Sauvignon Gris',
 'Muscadine',
 'Syrah-Grenache-Viognier',
 'Edelzwicker',
 'Jacquez',
 'Chardonnay-Riesling',
 'Gamay',
 'Syrah-Cabernet',
 'Touriga Nacional Blend',
 'Negroamaro',
 'Dornfelder',
 'Moscato Giallo',
 'Cabernet Pfeffer',
 'Morio Muskat',
 'Cabernet Sauvignon-Malbec',
 'Pinot Blanc-Viognier',
 'Pinot Nero',
 'Sangiovese Grosso',
 'Cabernet Sauvignon-Tempranillo',
 'Black Monukka',
 'Tempranillo-Syrah',
 'Chardonel',
 'Saperavi',
 'Madeira Blend',
 'Cabernet-Shiraz',
 'Cayuga',
 'Tinta Amarela',
 'Chelois',
 'Roussanne-Grenache Blanc',
 'Grenache Noir',
 'Viognier-Marsanne',
 'Apple',
 'Pinot Grigio-Sauvignon Blanc',
 'Viognier-Grenache Blanc',
 'Valvin Muscat',
 'Melon',
 'St. Vincent',
 'Chancellor',
 'Kerner',
 'Tinta Madeira',
 'Merlot-Petite Verdot',
 'Cabernet',
 'Cabernet Franc-Lemberger',
 'Pinot Blanc-Chardonnay',
 'Chardonnay-Albariño',
 'Cabernet Franc-Cabernet Sauvignon',
 'Silvaner',
 'Viognier-Valdiguié',
 'Prosecco',
 'Carignan-Grenache',
 'Chardonnay-Pinot Blanc',
 'Tannat-Syrah',
 'Rosado',
 "Muscat d'Alexandrie",
 'Alvarinho',
 'Alsace white blend',
 'Tannat-Cabernet',
 'Ugni Blanc-Colombard',
 'Savagnin',
 'Pinot Noir-Gamay',
 'Sylvaner',
 'Chenin Blanc-Chardonnay',
 'Provence red blend',
 'Altesse',
 'Provence white blend',
 'Carcajolu',
 'Marselan',
 'Colombard-Sauvignon Blanc',
 'Gros and Petit Manseng',
 'Jacquère',
 'Mauzac',
 'Merlot-Tannat',
 'Muscadelle',
 'Gros Manseng',
 'Chardonnay-Sauvignon',
 'Sauvignon',
 'Sauvignon-Sémillon',
 'Sauvignon Blanc-Chardonnay',
 'Chasselas',
 'Duras',
 "Loin de l'Oeil",
 'Chardonnay-Sauvignon Blanc',
 'Prunelard',
 'Gros Plant',
 'Colombard-Ugni Blanc',
 'Sacy',
 'Mansois',
 'Chardonnay-Pinot Gris',
 'Poulsard',
 'Sciaccerellu',
 'Tannat-Cabernet Franc',
 'Fer Servadou',
 'Tannat-Merlot',
 'Romorantin',
 'Braucol',
 'Trousseau',
 'Nielluciu',
 'Rolle',
 'Grolleau',
 'Carignan-Syrah',
 'Syrah-Carignan',
 'Folle Blanche',
 'Merlot-Grenache',
 'Muscadel',
 'Malbec-Cabernet Franc',
 'Tokay Pinot Gris',
 'Grenache Gris',
 'Petit Courbu',
 'Ondenc',
 'Frappato',
 'Catarratto',
 'Inzolia',
 'Monica',
 'Grillo',
 'Vernaccia',
 'Prugnolo Gentile',
 'Pinot Bianco',
 'Friulano',
 'Garganega',
 'Nerello Mascalese',
 'Cannonau',
 'Glera',
 'Verduzzo',
 'Verdicchio',
 'Carricante',
 'Corvina, Rondinella, Molinara',
 'Insolia',
 'Prié Blanc',
 'Zibibbo',
 'Turbiana',
 'Ruché',
 'Lambrusco di Sorbara',
 'Cesanese',
 'Pugnitello',
 'Tocai',
 'Pecorino',
 'Albanello',
 'Nosiola',
 'Perricone',
 'Albana',
 'Lambrusco',
 'Grechetto',
 'Carignano',
 'Torbato',
 'Pallagrello',
 'Aleatico',
 'Magliocco',
 'Nascetta',
 'Lambrusco Grasparossa',
 'Schiava',
 'Moscadello',
 'Durella',
 'Passerina',
 'Uva di Troia',
 'Raboso',
 'Marzemino',
 'Trebbiano Spoletino',
 'Freisa',
 'Nero di Troia',
 'Brachetto',
 'Pallagrello Bianco',
 'Veltliner',
 'Gaglioppo',
 'Piedirosso',
 'Susumaniello',
 'Vitovska',
 'Picolit',
 'Nerello Cappuccio',
 'Corvina',
 "Cesanese d'Affile",
 'Verduzzo Friulano',
 'Coda di Volpe',
 'Manzoni',
 'Timorasso',
 'Pigato',
 'Grignolino',
 'Groppello',
 'Pignoletto',
 'Ciliegiolo',
 'Mantonico',
 'Alicante',
 'Grecanico',
 'Casavecchia',
 'Nuragus',
 'Incrocio Manzoni',
 'Lambrusco Salamino',
 'Cococciola',
 'Bombino Bianco',
 'Pallagrello Nero',
 'Vespolina',
 'Rebo',
 'Traminer',
 'Malvasia di Candia',
 'Molinara',
 'Malvasia Istriana',
 'Erbaluce',
 'Vespaiolo',
 'Biancolella',
 'Greco Bianco',
 'Malvasia Nera',
 'Canaiolo',
 'Bombino Nero',
 'Bovale',
 'Gragnano',
 'Teroldego Rotaliano',
 'Trebbiano di Lugana',
 'Albarossa',
 'Malvar',
 'Verdeca',
 'Uvalino',
 'Vermentino Nero',
 'Moscato Rosa',
 'Biancale',
 'Ansonica',
 'Roviello',
 'Franconia',
 'Nasco',
 'Sirica',
 'Colorino',
 'Centesimino',
 'Catalanesca',
 'Favorita',
 'Tintilia',
 'Moscato di Noto',
 'Pignolo',
 'Asprinio',
 'Caprettone',
 'Tempranillo-Merlot',
 'Mencía',
 'Viura',
 'Garnacha Tintorera',
 'Verdejo-Viura',
 'Xarel-lo',
 'Pansa Blanca',
 'Moscatel',
 'Viura-Chardonnay',
 'Monastrell-Syrah',
 'Tinta de Toro',
 'Tinta Fina',
 'Maturana',
 'Godello',
 'Pedro Ximénez',
 'Tinto Fino',
 'Tinto del Pais',
 'Trepat',
 'Bobal',
 'Prieto Picudo',
 'Macabeo',
 'Mazuelo',
 'Tinta del Pais',
 'Verdil',
 'Treixadura',
 'Forcallà',
 'Viura-Verdejo',
 'Tinta del Toro',
 'Garnacha-Syrah',
 'Rufete',
 'Tempranillo-Shiraz',
 'Carineña',
 'Tempranillo Blanco',
 'Tinto Velasco',
 'Hondarrabi Zuri',
 'Doña Blanca',
 'Verdejo-Sauvignon Blanc',
 'Malvasia-Viura',
 'Shiraz-Cabernet Sauvignon',
 'Macabeo-Chardonnay',
 'Macabeo-Moscatel',
 'Cariñena-Garnacha',
 'Paralleda',
 'Airen',
 'Muscat of Alexandria',
 'Verdosilla',
 'Sauvignon Blanc-Verdejo',
 'Garnacha-Monastrell',
 'Moscatel de Alejandría',
 'Listán Negro',
 'Garnacha Blend',
 'Vidadillo',
 'Jaen',
 'Meseguera',
 'Garnacha-Tempranillo',
 'Merseguera-Sauvignon Blanc',
 'Shiraz-Tempranillo',
 'Monastrell-Petit Verdot',
 'Premsal',
 'Picapoll',
 'Garnacha-Cabernet',
 'Garnacha-Cariñena',
 'Babosa Negro',
 'Parraleta',
 'Bobal-Cabernet Sauvignon',
 'Portuguese Red',
 'Portuguese White',
 'Antão Vaz',
 'Sousão',
 'Avesso',
 'Tinta Miúda',
 'Portuguese Sparkling',
 'Bical',
 'Baga',
 'Cerceal',
 'Fernão Pires',
 'Arinto',
 'Encruzado',
 'Siria',
 'Alfrocheiro',
 'Loureiro-Arinto',
 'Cercial',
 'Loureiro',
 'Aragonez',
 'Tinta Barroca',
 'Castelão',
 'Tinta Roriz',
 'Trincadeira',
 'Portuguese Rosé',
 'Touriga Nacional-Cabernet Sauvignon',
 'Touriga Franca',
 'Moscatel Roxo',
 'Tinta Cao',
 'Baga-Touriga Nacional',
 'Aragonês',
 'Códega do Larinho',
 'Azal',
 'Moscatel Graúdo',
 'Viosinho',
 'Maria Gomes',
 'Vinhão',
 'Tinta Francisca',
 'Maria Gomes-Bical',
 'Gouveio',
 'Bastardo',
 'Bual',
 'Rabigato',
 'Alvarinho-Chardonnay',
 'Tinta Negra Mole',
 'Merlot-Syrah',
 'Sercial',
 'Malvasia Fina',
 'Jampal',
 'Trajadura',
 'Cabernet Franc-Carmenère',
 'País',
 'Carmenère-Cabernet Sauvignon',
 'Carmenère-Syrah',
 'Malbec-Carménère',
 'Muscatel',
 'Torontel',
 'Bonarda',
 'Malbec-Petit Verdot',
 'Malbec-Cabernet',
 'Cabernet Franc-Malbec',
 'Syrah-Malbec',
 'Malbec-Bonarda',
 'Malbec Blend',
 'Cabernet-Malbec',
 'Syrah-Bonarda',
 'Malbec-Tempranillo',
 'Shiraz-Malbec',
 'Weissburgunder',
 'Austrian Red Blend',
 'Gelber Muskateller',
 'St. Laurent',
 'Rotgipfler',
 'Zierfandler',
 'Welschriesling',
 'Roter Veltliner',
 'Zierfandler-Rotgipfler',
 'Neuburger',
 'Austrian white blend',
 'Morillon',
 'Rosenmuskateller',
 'Grauburgunder',
 'Blauburgunder',
 'Muskateller',
 'Roter Traminer',
 'Orangetraube',
 'Sämling',
 'Furmint',
 'Gelber Traminer',
 'Chardonnay Weissburgunder',
 'Shiraz-Viognier',
 'Shiraz-Grenache',
 'Tokay',
 'Shiraz-Cabernet',
 'Grenache-Shiraz',
 'Cabernet Sauvignon-Merlot-Shiraz',
 'Shiraz-Roussanne',
 'Durif',
 'Shiraz-Mourvèdre',
 'Früburgunder',
 'Rieslaner',
 'Spätburgunder',
 'Rivaner',
 'Elbling',
 'Schwartzriesling',
 'Silvaner-Traminer',
 'Trollinger',
 'Chenin Blanc-Sauvignon Blanc',
 'Pinotage-Merlot',
 'Merlot-Shiraz',
 'Merlot-Argaman',
 'Argaman',
 'Marawi',
 'Assyrtico',
 'Vilana',
 'Roditis',
 'Agiorgitiko',
 'Malagousia',
 'Assyrtiko',
 'Moschofilero',
 'Xinomavro',
 'Mavrodaphne',
 'Mavroudi',
 'Thrapsathiri',
 'Savatiano',
 'Plyto',
 'Sideritis',
 'Moschofilero-Chardonnay',
 'Aidani',
 'Malagouzia-Chardonnay',
 'Mavrotragano',
 'Robola',
 'Malagouzia',
 'Mandilaria',
 'Sauvignon Blanc-Assyrtiko',
 'Cabernet Sauvignon Grenache',
 'Roditis-Moschofilero',
 'Mavrokalavryta',
 'Dafni',
 'Kotsifali',
 'Athiri']

# Red Wine Varieties 
red_wine_varieties = [
    'Pinot Noir', 'Cabernet Sauvignon', 'Meritage', 'Red Blend', 'Merlot', 'Malbec', 'Cabernet Franc', 
    'Bordeaux-style Red Blend', 'Petite Sirah', 'Zinfandel', 'Syrah', 'Rhône-style Red Blend', 'G-S-M', 
    'Sangiovese', 'Cabernet Sauvignon-Syrah', 'Tempranillo', 'Grenache', 'Syrah-Grenache', 'Nero d’Avola', 
    'Mourvèdre', 'Barbera', 'Carmenère', 'Teroldego', 'Dolcetto', 'Primitivo', 'Gamay Noir', 'Lemberger', 
    'Nebbiolo', 'Shiraz', 'Tannat', 'Pinotage', 'Grenache-Carignan', 'Montepulciano', 'Graciano', 'Cinsault', 
    'Carignan', 'Valdiguié', 'Syrah-Mourvèdre', 'Blaufränkisch', 'Mondeuse', 'Scheurebe', 'Aglianico', 
    'Tempranillo Blend', 'Petit Manseng', 'Sagrantino', 'Merlot-Cabernet Sauvignon', 'Grenache Blend', 
    'Sangiovese Cabernet', 'Grenache-Mourvèdre', 'Cabernet Sauvignon-Barbera', 'Merlot-Cabernet', 'Refosco', 
    'Sangiovese-Cabernet Sauvignon', 'Syrah-Cabernet Sauvignon', 'Garnacha', 'Grenache-Syrah', 'Malbec-Syrah', 
    'Mourvèdre-Syrah', 'Cabernet Franc-Merlot', 'Merlot-Cabernet Franc', 'Syrah-Petite Sirah', 'Cabernet Blend', 
    'Syrah-Cabernet', 'Malbec-Tannat', 'Tempranillo-Cabernet Sauvignon', 'Cabernet Sauvignon-Carmenère', 
    'Malbec-Cabernet Sauvignon', 'Syrah-Grenache-Viognier', 'Malbec-Merlot', 'Merlot-Malbec', 'Cabernet Sauvignon-Merlot',
    'Cabernet Sauvignon-Sangiovese', 'Syrah-Viognier', 'Marsanne-Roussanne', 'Roussanne-Viognier', 'Viognier-Roussanne',
    'Cabernet Sauvignon-Cabernet Franc', 'Syrah-Tempranillo', 'Merlot-Cabernet Sauvignon', 'Alicante Bouschet', 'Barbera-Nebbiolo',
    'Cabernet Franc-Lemberger', 'Carignan-Syrah', 'Syrah-Carignan', 
    'Merlot-Grenache', 'Malbec-Cabernet Franc', 'Petite Verdot', 'Syrah-Merlot', 'Tannat-Cabernet Franc', 
    'Tannat-Cabernet', 'Malbec-Cabernet', 'Syrah-Cabernet Franc', 'Tempranillo-Garnacha', 'Monastrell', 
    'Cabernet Sauvignon-Shiraz', 'Shiraz-Cabernet Sauvignon', 'Monastrell-Syrah', 'Sangiovese-Syrah', 
    'Syrah-Mourvèdre', 'Petit Verdot', 'Cabernet Sauvignon-Syrah', 'Syrah-Cabernet Sauvignon', 'Tannat-Merlot', 
    'Cabernet Sauvignon-Malbec', 'Tempranillo-Syrah', 'Sangiovese Grosso', 'Nero di Troia', 'Primitivo', 
    'Negroamaro', 'Corvina', 'Rondinella', 'Molinara', 'Grenache Noir', 'Marselan', 'Tinta Amarela', 'Tinta de Toro', 'Tinta Fina', 'Tinto Fino', 'Tinto del Pais', 
    'Bobal', 'Prieto Picudo', 'Mazuelo', 'Maturana', 'Touriga Nacional', 'Touriga Franca' 'Garnacha', 'Syrah-Grenache',
    'Grenache-Syrah',  'Malbec-Syrah', 'Cabernet Franc-Merlot', 'Merlot-Cabernet Franc',
    'Syrah-Petite Sirah', 'Petit Verdot', 'Merlot-Malbec', 'Mourvèdre-Syrah', 'Sangiovese-Cabernet', 'Malbec-Cabernet Franc',
    'Cabernet Sauvignon-Cabernet Franc', 'Syrah-Cabernet', 'Syrah-Merlot', 'Tannat-Syrah', 'Cabernet Sauvignon-Shiraz',
    'Shiraz-Cabernet Sauvignon', 'Monastrell-Syrah', 'Sangiovese-Syrah', 'Syrah-Mourvèdre', 'Tannat-Cabernet Franc',
    'Malbec-Cabernet Sauvignon', 'Tempranillo-Syrah', 'Grenache Noir', 'Alicante Bouschet', 'Nebbiolo', 'Barbera',
    'Dolcetto', 'Sagrantino', 'Tannat', 'Aglianico', 'Carmenère', 'Pinotage', 'Touriga Nacional', 'Zinfandel', 
    'Primitivo', 'Negroamaro', 'Corvina', 'Molinara', 'Rondinella', 'Bobal', 'Cinsault', 'Carignan', 'Grenache-Carignan',
    'Merlot-Cabernet', 'Cabernet Franc-Lemberger', 'Merlot-Grenache', 'Carignan-Syrah', 'Syrah-Carignan', 'Valdiguié', 'Mondeuse',
    'Teroldego',   'Refosco', 'Lagrein', 'Marselan', 'Saperavi', 'Xinomavro', 'Blaufränkisch', 'Tinta Barroca', 'Touriga Franca', 
    'Aragonês',    'Trincadeira', 'Alfrocheiro', 'Castelão', 'Moreto', 'Alicante Henri Bouschet', 'Aragonês', 'Baga', 'Bastardo', 
    'Castelão', 'Espadeiro', 'Mourisco Tinto', 'Periquita', 'Rabo de Ovelha', 'Tinta Roriz', 'Vinhas Velhas', 'Sousão', 'Tinta Amarela',
    'Trincadeira', 'Alfrocheiro Preto', 'Tinta Caiada', 'Aragonez', 'Tinta Francisca', 'Mourvèdre (Monastrell)', 'Syrah-Grenache-Viognier'
    'Jaen', 'Garnacha-Tempranillo', 'Monastrell-Petit Verdot', 'Garnacha-Cabernet', 'Garnacha-Cariñena', 'Babosa Negro', 
    'Bobal-Cabernet Sauvignon', 'Portuguese Red',    'Antão Vaz', 'Sousão', 'Tinta Miúda', 'Bical', 'Baga', 
    'Aragonez', 'Tinta Barroca', 'Castelão', 'Tinta Roriz', 'Trincadeira',    'Touriga Nacional-Cabernet Sauvignon',
    'Touriga Franca', 'Aragonês', 'Baga-Touriga Nacional', 'Vinhão', 'Tinta Francisca', 'Cabernet Franc-Carmenère', 'País', 
    'Carmenère-Cabernet Sauvignon', 'Carmenère-Syrah', 'Malbec-Carménère', 'Bonarda', 'Malbec-Petit Verdot', 'Malbec-Cabernet','Cabernet Franc-Malbec', 'Syrah-Malbec', 
    'Malbec-Bonarda', 'Malbec Blend',    'Cabernet-Malbec', 'Syrah-Bonarda', 'Malbec-Tempranillo',
    'Shiraz-Malbec', 'Austrian Red Blend', 'Shiraz-Viognier', 'Shiraz-Grenache', 'Shiraz-Cabernet', 'Grenache-Shiraz', 'Cabernet Sauvignon-Merlot-Shiraz', 'Shiraz-Roussanne', 'Durif', 
    'Shiraz-Mourvèdre', 'Früburgunder',    'Spätburgunder', 'Marawi',
    'Agiorgitiko', 'Xinomavro', 'Mavrodaphne', 'Mavroudi', 'Kotsifali','Cabernet Sauvignon Grenache', 'Dafni', 'Athiri']

# White Wine Varieties
white_wine_varieties = ['Airen', 'Albariño', 'Alvarelhão', 'Auxerrois', 'Blanc du Bois', 'Chardonnay', 'Chardonnay-Viognier', 
    'Chenin Blanc', 'Colombard', 'Fumé Blanc', 'Garganega', 'Garnacha Blanca', 'Gewürztraminer',
    'Gewürztraminer-Riesling', 'Grenache Blanc', 'Grüner Veltliner', 'Johannisberg Riesling', 'Macabeo',
    'Malvasia', 'Malvasia-Viognier', 'Marsanne', 'Marsanne-Roussanne', 'Marsanne-Viognier', 'Melon', 'Moscato',
    'Muscat', 'Muscat Blanc', 'Muscat Canelli', 'Muscat of Alexandria', 'Muskat Ottonel', 'Müller-Thurgau',
    'Orange Muscat', 'Palomino', 'Pansa Blanca', 'Picpoul', 'Pinot Blanc', 'Pinot Grigio',
    'Pinot Grigio-Sauvignon Blanc', 'Pinot Gris', 'Rhône-style White Blend', 'Riesling', 'Rkatsiteli',
    'Roussanne', 'Roussanne-Viognier', 'Sauvignon Blanc', 'Sauvignon Blanc-Chenin Blanc', 'Sauvignon Blanc-Semillon',
    'Sauvignon Musqué', 'Semillon-Chardonnay', 'Seyval Blanc', 'Sémillon', 'Torrontés', 'Traminette', 'Trebbiano',
    'Ugni Blanc', 'Verdejo', 'Verdelho', 'Vermentino', 'Vidal Blanc', 'Vignoles', 'Viognier', 'Viognier-Chardonnay',
    'Viognier-Roussanne', 'White Blend', 'Xarel-lo', 'Pinot Gris', 'Riesling', 'Chardonnay', 'Chenin Blanc', 'Sauvignon Blanc', 'Albariño', 'Viognier', 
    'Grenache Blanc', 'Fumé Blanc', 'Gewürztraminer', 'Vignoles', 'White Blend', 'Pinot Blanc', 'Verdelho', 
    'Marsanne', 'Syrah-Grenache', 'Grüner Veltliner', 'Pinot Grigio', 'Roussanne', 'Muscat Blanc à Petits Grains', 
    'Rhône-style White Blend', 'Muskat Ottonel', 'Vermentino', 'Muscat', 'Moscato', 'Traminette', 'Sémillon', 
    'Marsanne-Viognier', 'Semillon-Sauvignon Blanc', 'Seyval Blanc', 'Muscat Canelli', 'Sauvignon Blanc-Semillon', 
    'Bordeaux-style White Blend', 'Vidal Blanc', 'Gewürztraminer-Riesling', 'Colombard', 'Auxerrois', 'Muskat', 
    'Malvasia', 'Falanghina', 'Champagne Blend', 'Tocai Friulano', 'Chardonnay-Semillon', 'Viognier-Roussanne', 
    'Orange Muscat', 'Rkatsiteli']
   
    
rosé_wine_list = ['Rosé Wine','Portuguese Rosé','Rosé']
   
sparkling_wine_list = ['Sparkling Wine',  'Sparkling Blend', 'Champagne Blend', 'Portuguese Sparkling']

dessert_wine_list = ['Port', 'Muscat Blanc à Petits Grains', 'Orange Muscat', 'Moscato', 'Sherry',
                     'White Port', 'Tokay', 'Merlot-Syrah', 'Merlot-Argaman', 'Argaman','Moscatel', 'Muscatel', 'Mavrodaphne']
                  

categories = {
    "Red Wines": [],
    "White Wines": [],
    "Rosé/Sparkling": [],
    "Specialty Wines": [],
}


#for wine in wine_list:
    #if wine in red_wine_varieties
    #categories["Red Wines"].append(wine)
    
    #elif wine in white_wines:
        #categories["Red Wines"].append(wine)
    
    #elif win

# %%
len(red_wine_varieties)
# Out:
# 269

# %%
len(white_wine_varieties)
# Out:
# 111

# %%
len(white_wine_varieties)

# %%
len(dessert_wine_list)
# Out:
# 13

# %%
13+8+111+269+111
# Out:
# 512

# %%
647-512
# Out:
# 135

# %%
# !pwd
# Out:
# /home/diogo_rebelo/code/Wine-Recommendation-System
