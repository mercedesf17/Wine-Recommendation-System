# %%
''' This the Original List of Wine Varieties.'''

wine_list = ['Pinot Gris',
 'Riesling',
 'Pinot Noir',
 'Cabernet Sauvignon',
 'Chardonnay',
 'Meritage',
 'Red Blend',
 'Merlot',
 'Chenin Blanc',
 'Sauvignon Blanc',
 'Malbec',
 'Cabernet Franc',
 'Bordeaux-style Red Blend',
 'Petite Sirah',
 'Zinfandel',
 'Albariño',
 'Viognier',
 'Grenache Blanc',
 'Syrah',
 'Rhône-style Red Blend',
 'G-S-M',
 'Fumé Blanc',
 'Gewürztraminer',
 'Sangiovese',
 'Cabernet Sauvignon-Syrah',
 'Vignoles',
 'White Blend',
 'Rosé',
 'Sparkling Blend',
 'Tempranillo',
 'Pinot Blanc',
 'Verdelho',
 'Grenache',
 'Marsanne',
 'Syrah-Grenache',
 'Grüner Veltliner',
 'Pinot Grigio',
 'Roussanne',
 "Nero d'Avola",
 'Muscat Blanc à Petits Grains',
 'Petit Verdot',
 'Charbono',
 'Rhône-style White Blend',
 'Mourvèdre',
 'Pinot Meunier',
 'Cabernet Sauvignon-Sangiovese',
 'Port',
 'Muskat Ottonel',
 'Claret',
 'Syrah-Viognier',
 'Marsanne-Roussanne',
 'Barbera',
 'Carmenère',
 'Vermentino',
 'Muscat',
 'Teroldego',
 'Moscato',
 'Traminette',
 'Chambourcin',
 'Sémillon',
 'Marsanne-Viognier',
 'Touriga Nacional',
 'Syrah-Cabernet Sauvignon',
 'Semillon-Sauvignon Blanc',
 'Garnacha',
 'Grenache-Syrah',
 'Seyval Blanc',
 'Muscat Canelli',
 'Dolcetto',
 'Sauvignon Blanc-Semillon',
 'Bordeaux-style White Blend',
 'Merlot-Cabernet Franc',
 'Syrah-Petite Sirah',
 'Primitivo',
 'Cabernet Blend',
 'Gamay Noir',
 'Vidal Blanc',
 'Gewürztraminer-Riesling',
 'Lemberger',
 'Nebbiolo',
 'Blanc du Bois',
 'Shiraz',
 'Roussanne-Viognier',
 'Colombard',
 'Auxerrois',
 'Muskat',
 'Cabernet Franc-Merlot',
 'Tannat',
 'Malvasia',
 'Pinotage',
 'Falanghina',
 'Grenache-Carignan',
 'Champagne Blend',
 'Tocai Friulano',
 'Chardonnay-Semillon',
 'Norton',
 'Montepulciano',
 'Graciano',
 'Cinsault',
 'Carignan',
 'Symphony',
 'Black Muscat',
 'Johannisberg Riesling',
 'Arneis',
 'Valdiguié',
 'Syrah-Mourvèdre',
 'Blaufränkisch',
 'Mondeuse',
 'Cabernet Merlot',
 'Petite Verdot',
 'Merlot-Malbec',
 'Mourvèdre-Syrah',
 'Clairette',
 'Malbec-Syrah',
 'Diamond',
 'Monastrell',
 'Scheurebe',
 'Aglianico',
 'Tempranillo Blend',
 'Petit Manseng',
 'Siegerrebe',
 'Trousseau Gris',
 'Cabernet Sauvignon-Merlot',
 'Grenache Blend',
 'Sagrantino',
 'Merlot-Cabernet Sauvignon',
 'Greco',
 'Aligoté',
 'Sangiovese Cabernet',
 'Muscat Blanc',
 'Viognier-Roussanne',
 'Rosato',
 'Cabernet Sauvignon-Cabernet Franc',
 'Baco Noir',
 'Barbera-Nebbiolo',
 'Piquepoul Blanc',
 'Chenin Blanc-Viognier',
 'Orange Muscat',
 'Rkatsiteli',
 'Carignane',
 'Counoise',
 'Sherry',
 'Debit',
 'Grenache-Mourvèdre',
 'Pinot-Chardonnay',
 'Syrah-Tempranillo',
 'Cabernet Sauvignon-Barbera',
 'Merlot-Cabernet',
 'Refosco',
 'Sangiovese-Cabernet Sauvignon',
 'Viognier-Gewürztraminer',
 'Müller-Thurgau',
 'Vidal',
 'Chardonnay-Viognier',
 'Lagrein',
 'Mataro',
 'Cortese',
 'Ugni Blanc',
 'Semillon-Chardonnay',
 'Fiano',
 'Trebbiano',
 'Picpoul',
 'Tempranillo-Garnacha',
 'Palomino',
 'Touriga',
 'Madeleine Angevine',
 'Alvarelhão',
 'Malbec-Merlot',
 'Viognier-Chardonnay',
 'Pinot Blanc-Pinot Noir',
 'Muscat Hamburg',
 'Sauvignon Blanc-Chenin Blanc',
 'Pinot Gris-Gewürztraminer',
 'Sauvignon Musqué',
 'Ribolla Gialla',
 'Roussanne-Marsanne',
 'Sangiovese-Syrah',
 'Mission',
 'Marquette',
 'Malbec-Tannat',
 'Tempranillo-Cabernet Sauvignon',
 'Cabernet Sauvignon-Carmenère',
 'Malvasia Bianca',
 'Negrette',
 'Torrontés',
 'Cabernet-Syrah',
 'Garnacha Blanca',
 'Alicante Bouschet',
 'Syrah-Cabernet Franc',
 'Verdejo',
 'Syrah-Merlot',
 'Pinot Auxerrois',
 'Cabernet Sauvignon-Shiraz',
 'Abouriou',
 'Pinot Noir-Syrah',
 'Syrah-Petit Verdot',
 'Souzao',
 'White Port',
 'Malbec-Cabernet Sauvignon',
 'White Riesling',
 'Zweigelt',
 'Riesling-Chardonnay',
 'Sauvignon Gris',
 'Muscadine',
 'Syrah-Grenache-Viognier',
 'Edelzwicker',
 'Jacquez',
 'Chardonnay-Riesling',
 'Gamay',
 'Syrah-Cabernet',
 'Touriga Nacional Blend',
 'Negroamaro',
 'Dornfelder',
 'Moscato Giallo',
 'Cabernet Pfeffer',
 'Morio Muskat',
 'Cabernet Sauvignon-Malbec',
 'Pinot Blanc-Viognier',
 'Pinot Nero',
 'Sangiovese Grosso',
 'Cabernet Sauvignon-Tempranillo',
 'Black Monukka',
 'Tempranillo-Syrah',
 'Chardonel',
 'Saperavi',
 'Madeira Blend',
 'Cabernet-Shiraz',
 'Cayuga',
 'Tinta Amarela',
 'Chelois',
 'Roussanne-Grenache Blanc',
 'Grenache Noir',
 'Viognier-Marsanne',
 'Apple',
 'Pinot Grigio-Sauvignon Blanc',
 'Viognier-Grenache Blanc',
 'Valvin Muscat',
 'Melon',
 'St. Vincent',
 'Chancellor',
 'Kerner',
 'Tinta Madeira',
 'Merlot-Petite Verdot',
 'Cabernet',
 'Cabernet Franc-Lemberger',
 'Pinot Blanc-Chardonnay',
 'Chardonnay-Albariño',
 'Cabernet Franc-Cabernet Sauvignon',
 'Silvaner',
 'Viognier-Valdiguié',
 'Prosecco',
 'Carignan-Grenache',
 'Chardonnay-Pinot Blanc',
 'Tannat-Syrah',
 'Rosado',
 "Muscat d'Alexandrie",
 'Alvarinho',
 'Alsace white blend',
 'Tannat-Cabernet',
 'Ugni Blanc-Colombard',
 'Savagnin',
 'Pinot Noir-Gamay',
 'Sylvaner',
 'Chenin Blanc-Chardonnay',
 'Provence red blend',
 'Altesse',
 'Provence white blend',
 'Carcajolu',
 'Marselan',
 'Colombard-Sauvignon Blanc',
 'Gros and Petit Manseng',
 'Jacquère',
 'Mauzac',
 'Merlot-Tannat',
 'Muscadelle',
 'Gros Manseng',
 'Chardonnay-Sauvignon',
 'Sauvignon',
 'Sauvignon-Sémillon',
 'Sauvignon Blanc-Chardonnay',
 'Chasselas',
 'Duras',
 "Loin de l'Oeil",
 'Chardonnay-Sauvignon Blanc',
 'Prunelard',
 'Gros Plant',
 'Colombard-Ugni Blanc',
 'Sacy',
 'Mansois',
 'Chardonnay-Pinot Gris',
 'Poulsard',
 'Sciaccerellu',
 'Tannat-Cabernet Franc',
 'Fer Servadou',
 'Tannat-Merlot',
 'Romorantin',
 'Braucol',
 'Trousseau',
 'Nielluciu',
 'Rolle',
 'Grolleau',
 'Carignan-Syrah',
 'Syrah-Carignan',
 'Folle Blanche',
 'Merlot-Grenache',
 'Muscadel',
 'Malbec-Cabernet Franc',
 'Tokay Pinot Gris',
 'Grenache Gris',
 'Petit Courbu',
 'Ondenc',
 'Frappato',
 'Catarratto',
 'Inzolia',
 'Monica',
 'Grillo',
 'Vernaccia',
 'Prugnolo Gentile',
 'Pinot Bianco',
 'Friulano',
 'Garganega',
 'Nerello Mascalese',
 'Cannonau',
 'Glera',
 'Verduzzo',
 'Verdicchio',
 'Carricante',
 'Corvina, Rondinella, Molinara',
 'Insolia',
 'Prié Blanc',
 'Zibibbo',
 'Turbiana',
 'Ruché',
 'Lambrusco di Sorbara',
 'Cesanese',
 'Pugnitello',
 'Tocai',
 'Pecorino',
 'Albanello',
 'Nosiola',
 'Perricone',
 'Albana',
 'Lambrusco',
 'Grechetto',
 'Carignano',
 'Torbato',
 'Pallagrello',
 'Aleatico',
 'Magliocco',
 'Nascetta',
 'Lambrusco Grasparossa',
 'Schiava',
 'Moscadello',
 'Durella',
 'Passerina',
 'Uva di Troia',
 'Raboso',
 'Marzemino',
 'Trebbiano Spoletino',
 'Freisa',
 'Nero di Troia',
 'Brachetto',
 'Pallagrello Bianco',
 'Veltliner',
 'Gaglioppo',
 'Piedirosso',
 'Susumaniello',
 'Vitovska',
 'Picolit',
 'Nerello Cappuccio',
 'Corvina',
 "Cesanese d'Affile",
 'Verduzzo Friulano',
 'Coda di Volpe',
 'Manzoni',
 'Timorasso',
 'Pigato',
 'Grignolino',
 'Groppello',
 'Pignoletto',
 'Ciliegiolo',
 'Mantonico',
 'Alicante',
 'Grecanico',
 'Casavecchia',
 'Nuragus',
 'Incrocio Manzoni',
 'Lambrusco Salamino',
 'Cococciola',
 'Bombino Bianco',
 'Pallagrello Nero',
 'Vespolina',
 'Rebo',
 'Traminer',
 'Malvasia di Candia',
 'Molinara',
 'Malvasia Istriana',
 'Erbaluce',
 'Vespaiolo',
 'Biancolella',
 'Greco Bianco',
 'Malvasia Nera',
 'Canaiolo',
 'Bombino Nero',
 'Bovale',
 'Gragnano',
 'Teroldego Rotaliano',
 'Trebbiano di Lugana',
 'Albarossa',
 'Malvar',
 'Verdeca',
 'Uvalino',
 'Vermentino Nero',
 'Moscato Rosa',
 'Biancale',
 'Ansonica',
 'Roviello',
 'Franconia',
 'Nasco',
 'Sirica',
 'Colorino',
 'Centesimino',
 'Catalanesca',
 'Favorita',
 'Tintilia',
 'Moscato di Noto',
 'Pignolo',
 'Asprinio',
 'Caprettone',
 'Tempranillo-Merlot',
 'Mencía',
 'Viura',
 'Garnacha Tintorera',
 'Verdejo-Viura',
 'Xarel-lo',
 'Pansa Blanca',
 'Moscatel',
 'Viura-Chardonnay',
 'Monastrell-Syrah',
 'Tinta de Toro',
 'Tinta Fina',
 'Maturana',
 'Godello',
 'Pedro Ximénez',
 'Tinto Fino',
 'Tinto del Pais',
 'Trepat',
 'Bobal',
 'Prieto Picudo',
 'Macabeo',
 'Mazuelo',
 'Tinta del Pais',
 'Verdil',
 'Treixadura',
 'Forcallà',
 'Viura-Verdejo',
 'Tinta del Toro',
 'Garnacha-Syrah',
 'Rufete',
 'Tempranillo-Shiraz',
 'Carineña',
 'Tempranillo Blanco',
 'Tinto Velasco',
 'Hondarrabi Zuri',
 'Doña Blanca',
 'Verdejo-Sauvignon Blanc',
 'Malvasia-Viura',
 'Shiraz-Cabernet Sauvignon',
 'Macabeo-Chardonnay',
 'Macabeo-Moscatel',
 'Cariñena-Garnacha',
 'Paralleda',
 'Airen',
 'Muscat of Alexandria',
 'Verdosilla',
 'Sauvignon Blanc-Verdejo',
 'Garnacha-Monastrell',
 'Moscatel de Alejandría',
 'Listán Negro',
 'Garnacha Blend',
 'Vidadillo',
 'Jaen',
 'Meseguera',
 'Garnacha-Tempranillo',
 'Merseguera-Sauvignon Blanc',
 'Shiraz-Tempranillo',
 'Monastrell-Petit Verdot',
 'Premsal',
 'Picapoll',
 'Garnacha-Cabernet',
 'Garnacha-Cariñena',
 'Babosa Negro',
 'Parraleta',
 'Bobal-Cabernet Sauvignon',
 'Portuguese Red',
 'Portuguese White',
 'Antão Vaz',
 'Sousão',
 'Avesso',
 'Tinta Miúda',
 'Portuguese Sparkling',
 'Bical',
 'Baga',
 'Cerceal',
 'Fernão Pires',
 'Arinto',
 'Encruzado',
 'Siria',
 'Alfrocheiro',
 'Loureiro-Arinto',
 'Cercial',
 'Loureiro',
 'Aragonez',
 'Tinta Barroca',
 'Castelão',
 'Tinta Roriz',
 'Trincadeira',
 'Portuguese Rosé',
 'Touriga Nacional-Cabernet Sauvignon',
 'Touriga Franca',
 'Moscatel Roxo',
 'Tinta Cao',
 'Baga-Touriga Nacional',
 'Aragonês',
 'Códega do Larinho',
 'Azal',
 'Moscatel Graúdo',
 'Viosinho',
 'Maria Gomes',
 'Vinhão',
 'Tinta Francisca',
 'Maria Gomes-Bical',
 'Gouveio',
 'Bastardo',
 'Bual',
 'Rabigato',
 'Alvarinho-Chardonnay',
 'Tinta Negra Mole',
 'Merlot-Syrah',
 'Sercial',
 'Malvasia Fina',
 'Jampal',
 'Trajadura',
 'Cabernet Franc-Carmenère',
 'País',
 'Carmenère-Cabernet Sauvignon',
 'Carmenère-Syrah',
 'Malbec-Carménère',
 'Muscatel',
 'Torontel',
 'Bonarda',
 'Malbec-Petit Verdot',
 'Malbec-Cabernet',
 'Cabernet Franc-Malbec',
 'Syrah-Malbec',
 'Malbec-Bonarda',
 'Malbec Blend',
 'Cabernet-Malbec',
 'Syrah-Bonarda',
 'Malbec-Tempranillo',
 'Shiraz-Malbec',
 'Weissburgunder',
 'Austrian Red Blend',
 'Gelber Muskateller',
 'St. Laurent',
 'Rotgipfler',
 'Zierfandler',
 'Welschriesling',
 'Roter Veltliner',
 'Zierfandler-Rotgipfler',
 'Neuburger',
 'Austrian white blend',
 'Morillon',
 'Rosenmuskateller',
 'Grauburgunder',
 'Blauburgunder',
 'Muskateller',
 'Roter Traminer',
 'Orangetraube',
 'Sämling',
 'Furmint',
 'Gelber Traminer',
 'Chardonnay Weissburgunder',
 'Shiraz-Viognier',
 'Shiraz-Grenache',
 'Tokay',
 'Shiraz-Cabernet',
 'Grenache-Shiraz',
 'Cabernet Sauvignon-Merlot-Shiraz',
 'Shiraz-Roussanne',
 'Durif',
 'Shiraz-Mourvèdre',
 'Früburgunder',
 'Rieslaner',
 'Spätburgunder',
 'Rivaner',
 'Elbling',
 'Schwartzriesling',
 'Silvaner-Traminer',
 'Trollinger',
 'Chenin Blanc-Sauvignon Blanc',
 'Pinotage-Merlot',
 'Merlot-Shiraz',
 'Merlot-Argaman',
 'Argaman',
 'Marawi',
 'Assyrtico',
 'Vilana',
 'Roditis',
 'Agiorgitiko',
 'Malagousia',
 'Assyrtiko',
 'Moschofilero',
 'Xinomavro',
 'Mavrodaphne',
 'Mavroudi',
 'Thrapsathiri',
 'Savatiano',
 'Plyto',
 'Sideritis',
 'Moschofilero-Chardonnay',
 'Aidani',
 'Malagouzia-Chardonnay',
 'Mavrotragano',
 'Robola',
 'Malagouzia',
 'Mandilaria',
 'Sauvignon Blanc-Assyrtiko',
 'Cabernet Sauvignon Grenache',
 'Roditis-Moschofilero',
 'Mavrokalavryta',
 'Dafni',
 'Kotsifali',
 'Athiri']

# %%
import re
from unidecode import unidecode
def clean_strings(input_list):
    # Step 1 & 2: Lower case each string and remove special characters
    cleaned_list = [re.sub(r'[^a-zA-Z0-9\s]', '', item.lower()) for item in input_list]
    # Step 3: Replace non-standard English letters with their standard equivalents
    cleaned_list = [unidecode(item) for item in cleaned_list]
    return cleaned_list

processed_wine_list = clean_strings(wine_list)

print(len(processed_wine_list))

''' Split into smaller Steps to be easy on ChatGPT to standerdize'''

wines1 = processed_wine_list[0:100]
wines2 = processed_wine_list[100:200]
wines3 = processed_wine_list[200:300]
wines4 = processed_wine_list[300:400]
wines5 = processed_wine_list[400:500]
wines6 = processed_wine_list[500:600]
wines7 = processed_wine_list[600:]  # This will contain the remaining 34 items
# Out:
# 634

# %%
print(len(wines1))

''' After ChatGPT staderdization '''

wines1 =  [
    'pinot gris', 'riesling', 'pinot noir', 'cabernet sauvignon', 'chardonnay',
    'meritage', 'red blend', 'merlot', 'chenin blanc', 'sauvignon blanc',
    'malbec', 'cabernet franc', 'bordeauxstyle red blend', 'petite sirah',
    'zinfandel', 'albariño', 'viognier', 'grenache blanc', 'syrah',
    'rhônestyle red blend', 'gsm', 'fumé blanc', 'gewürztraminer', 'sangiovese',
    'cabernet sauvignonsyrah', 'vignoles', 'white blend', 'rosé', 'sparkling blend',
    'tempranillo', 'pinot blanc', 'verdelho', 'grenache', 'marsanne',
    'syrahgrenache', 'grüner veltliner', 'pinot grigio', 'roussanne',
    'nero d’avola', 'muscat blanc à petits grains', 'petit verdot', 'charbono',
    'rhônestyle white blend', 'mourvèdre', 'pinot meunier',
    'cabernet sauvignonsangiovese', 'port', 'muskat ottonel', 'claret',
    'syrahviognier', 'marsanneroussanne', 'barbera', 'carmenère', 'vermentino',
    'muscat', 'teroldego', 'moscato', 'traminette', 'chambourcin', 'sémillon',
    'marsanneviognier', 'touriga nacional', 'syrahcabernet sauvignon',
    'semillonsauvignon blanc', 'garnacha', 'grenachesyrah', 'seyval blanc',
    'muscat canelli', 'dolcetto', 'sauvignon blancsémillon',
    'bordeauxstyle white blend', 'merlotcabernet franc', 'syrahpetite sirah',
    'primitivo', 'cabernet blend', 'gamay noir', 'vidal blanc',
    'gewürztraminerriesling', 'lemberger', 'nebbiolo', 'blanc du bois', 'shiraz',
    'roussanneviognier', 'colombard', 'auxerrois', 'muskat',
    'cabernet francmerlot', 'tannat', 'malvasia', 'pinotage', 'falanghina',
    'grenachecarignan', 'champagne blend', 'tocai friulano',
    'chardonnaysemillon', 'norton', 'montepulciano', 'graciano', 'cinsault',
    'carignan'
]
# Out:
# 100

# %%
red_wines1 = [
        'merlot', 'cabernet sauvignon', 'pinot noir', 'shiraz', 'zinfandel', 'malbec', 'syrah', 'tempranillo',
        'sangiovese', 'nebbiolo', 'grenache', 'barbera', 'petite sirah', 'mourvèdre', 'cabernet franc',
        'meritage', 'red blend', 'bordeauxstyle red blend', 'rhônestyle red blend', 'gsm',
        'cabernet sauvignonsyrah', 'syrahgrenache', 'cabernet sauvignonsangiovese', 'primitivo', 'dolcetto',
        'tannat', 'carignan', 'carmenère', 'grenachecarignan', 'montepulciano', 'nero d’avola', 'petit verdot',
        'pinotage', 'syrahcabernet sauvignon', 'syrahpetite sirah', 'touriga nacional', 'graciano', 'gamay noir',
        'claret', 'cabernet blend', 'merlotcabernet franc'
    ]

white_wines1 = [ 
        'chardonnay', 'sauvignon blanc', 'pinot gris', 'pinot grigio', 'riesling', 'viognier', 'gewürztraminer',
        'chenin blanc', 'semillon', 'moscato', 'albariño', 'grenache blanc', 'marsanne', 'roussanne',
        'white blend', 'fumé blanc', 'vignoles', 'pinot blanc', 'verdelho', 'grüner veltliner', 'muscat blanc à petits grains',
        'sémillon', 'marsanneviognier', 'roussanneviognier', 'viogniermarsanneroussanne', 'marsanneroussanne'
    ]

rose_wines1 = [
    'rosé'
]

sparkling_wines1 = [
    'sparkling blend', 'champagne blend'
]

dessert_wines1 = [
    'port', 'moscato', 'muscat', 'late harvest', 'ice wine', 'sauternes'
]

print(len(red_wines1))
print(len(white_wines1))
print(len(rose_wines1))
print(len(sparkling_wines1))
print(len(dessert_wines1))
print(len(red_wines1)+len(white_wines1)+len(rose_wines1)+len(sparkling_wines1)+len(dessert_wines1))
100-76
# Out:
# 41
# 26
# 1
# 2
# 6
# 76
# 24

# %%
wines2 = ['symphony',
 'black muscat',
 'johannisberg riesling',
 'arneis',
 'valdigui',
 'syrahmourvèdre',
 'blaufränkisch',
 'mondeuse',
 'cabernet merlot',
 'petite verdot',
 'merlotmalbec',
 'mourvèdresyrah',
 'clairette',
 'malbecsyrah',
 'diamond',
 'monastrell',
 'scheurebe',
 'aglianico',
 'tempranillo blend',
 'petit manseng',
 'siegerrebe',
 'trousseau gris',
 'cabernet sauvignonmerlot',
 'grenache blend',
 'sagrantino',
 'merlotcabernet sauvignon',
 'greco',
 'aligoté',
 'sangiovese cabernet',
 'muscat blanc',
 'viognierroussanne',
 'rosato',
 'cabernet sauvignoncabernet franc',
 'baco noir',
 'barberanebbiolo',
 'piquepoul blanc',
 'chenin blancviognier',
 'orange muscat',
 'rkatsiteli',
 'carignane',
 'counoise',
 'sherry',
 'debit',
 'grenachemourvèdre',
 'pinotchardonnay',
 'syrahtempranillo',
 'cabernet sauvignonbarbera',
 'merlotcabernet',
 'refosco',
 'sangiovesecabernet sauvignon',
 'viogniergewürztraminer',
 'müllerthurgau',
 'vidal',
 'chardonnayviognier',
 'lagrein',
 'mataro',
 'cortese',
 'ugni blanc',
 'semillonchardonnay',
 'fiano',
 'trebbiano',
 'picpoul',
 'tempranillogarnacha',
 'palomino',
 'touriga',
 'madeleine angevine',
 'alvarelhão',
 'malbecmerlot',
 'viognierchardonnay',
 'pinot blancpinot noir',
 'muscat hamburg',
 'sauvignon blancchenin blanc',
 'pinot grisgewürztraminer',
 'sauvignon musqué',
 'ribolla gialla',
 'roussannemarsanne',
 'sangiovesesyrah',
 'mission',
 'marquette',
 'malbectannat',
 'tempranillocabernet sauvignon',
 'cabernet sauvignoncarmenère',
 'malvasia bianca',
 'negrette',
 'torrontés',
 'cabernetsyrah',
 'garnacha blanca',
 'alicante bouschet',
 'syrahcabernet franc',
 'verdejo',
 'syrahmerlot',
 'pinot auxerrois',
 'cabernet sauvignonshiraz',
 'abouriou',
 'pinot noirsyrah',
 'syrahpetit verdot',
 'souzao',
 'white port',
 'malbeccabernet sauvignon',
 'white riesling']

# %%
red_wines2 = ['blaufränkisch', 'mondeuse', 'syrahmourvèdre', 'mourvèdresyrah', 'malbecsyrah', 'monastrell', 
                 'aglianico', 'sagrantino', 'aligoté', 'baco noir', 'barberanebbiolo', 'carignane', 'grenachemourvèdre', 
                 'syrahtempranillo', 'cabernet sauvignonbarbera', 'refosco', 'sangiovesecabernet sauvignon', 
                 'lagrein', 'mataro', 'negrette', 'cabernetsyrah', 'alicante bouschet', 'syrahcabernet franc', 
                 'syrahmerlot', 'cabernet sauvignonshiraz', 'pinot noirsyrah', 'syrahpetit verdot', 'malbectannat', 
                 'tempranillocabernet sauvignon', 'cabernet sauvignoncarmenère', 'malbecmerlot', 'sangiovesesyrah', 
                 'tempranillogarnacha', 'sangiovese cabernet', 'grenache blend', 'merlotcabernet sauvignon', 
                 'merlotcabernet', 'cabernet merlot', 'petite verdot', 'merlotmalbec']

white_wines2 = ['johannisberg riesling', 'arneis', 'clairette', 'diamond', 'petit manseng', 'siegerrebe', 
                   'trousseau gris', 'greco', 'muscat blanc', 'viognierroussanne', 'rosato', 
                   'piquepoul blanc', 'chenin blancviognier', 'orange muscat', 'rkatsiteli', 'debit', 
                   'pinotchardonnay', 'müllerthurgau', 'vidal', 'chardonnayviognier', 'cortese', 'ugni blanc', 
                   'semillonchardonnay', 'fiano', 'trebbiano', 'picpoul', 'palomino', 'touriga', 
                   'madeleine angevine', 'alvarelhão', 'viognierchardonnay', 'sauvignon blancchenin blanc', 
                   'pinot grisgewürztraminer', 'sauvignon musqué', 'ribolla gialla', 'roussannemarsanne', 
                   'malvasia bianca', 'torrontés', 'garnacha blanca', 'verdejo', 'pinot auxerrois', 
                   'abouriou', 'white port', 'white riesling']

rose_wines2 = ['rosato']

sparkling_wines2 = []

dessert_wines2 = ['scheurebe', 'muscat hamburg', 'orange muscat', 'white port', 'sherry']

missing_wines2 = ['symphony', 'black muscat', 'valdigui', 'cabernet sauvignonmerlot', 'cabernet sauvignoncabernet franc',
                     'tempranillo blend', 'viogniergewürztraminer', 'souzao', 'malbeccabernet sauvignon']
    
print(len(red_wines2))
print(len(white_wines2))
print(len(rose_wines2))
print(len(sparkling_wines2))
print(len(dessert_wines2))
print(len(red_wines2)+len(white_wines2)+len(rose_wines2)+len(sparkling_wines2)+len(dessert_wines2))
print(len(missing_wines2))
# Out:
# 40
# 44
# 1
# 0
# 5
# 90
# 9

# %%
wines3 = [
    'zweigelt', 'rieslingchardonnay', 'sauvignon gris', 'muscadine', 'syrahgrenacheviognier', 'edelzwicker', 'jacquez',
    'chardonnayriesling', 'gamay', 'syrahcabernet', 'touriga nacional blend', 'negroamaro', 'dornfelder', 'moscato giallo',
    'cabernet pfeffer', 'morio muskat', 'cabernet sauvignonmalbec', 'pinot blancviognier', 'pinot nero', 'sangiovese grosso',
    'cabernet sauvignontempranillo', 'black monukka', 'tempranillosyrah', 'chardonel', 'saperavi', 'madeira blend',
    'cabernetshiraz', 'cayuga', 'tinta amarela', 'chelois', 'roussannegrenache blanc', 'grenache noir', 'viogniermarsanne',
    'apple', 'pinot grigiosauvignon blanc', 'viogniergrenache blanc', 'valvin muscat', 'melon', 'st vincent', 'chancellor',
    'kerner', 'tinta madeira', 'merlotpetite verdot', 'cabernet', 'cabernet franclemberger', 'pinot blancchardonnay',
    'chardonnayalbario', 'cabernet franccabernet sauvignon', 'silvaner', 'viogniervaldigui', 'prosecco', 'carignangrenache',
    'chardonnaypinot blanc', 'tannatsyrah', 'rosado', 'muscat dalexandrie', 'alvarinho', 'alsace white blend', 'tannatcabernet',
    'ugni blanccolombard', 'savagnin', 'pinot noirgamay', 'sylvaner', 'chenin blancchardonnay', 'provence red blend', 'altesse',
    'provence white blend', 'carcajolu', 'marselan', 'colombardsauvignon blanc', 'gros and petit manseng', 'jacquère', 'mauzac',
    'merlottannat', 'muscadelle', 'gros manseng', 'chardonnaysauvignon', 'sauvignon', 'sauvignonsmillon', 'sauvignon blancchardonnay',
    'chasselas', 'duras', "loin de l'oeil", 'chardonnaysauvignon blanc', 'prunelard', 'gros plant', 'colombardugni blanc', 'sacy',
    'mansois', 'chardonnaypinot gris', 'poulsard', 'sciaccerellu', 'tannatcabernet franc', 'fer servadou', 'tannatmerlot', 'romorantin',
    'braucol', 'trousseau', 'nielluciu', 'rolle'
]

# %%
red_wines3 = [
    'zweigelt', 'syrahgrenacheviognier', 'gamay', 'syrahcabernet', 'negroamaro', 'dornfelder',
    'cabernet sauvignonmalbec', 'pinot nero', 'sangiovese grosso', 'cabernet sauvignontempranillo',
    'tempranillosyrah', 'cabernetshiraz', 'grenache noir', 'merlotpetite verdot', 'cabernet',
    'cabernet franclemberger', 'cabernet franccabernet sauvignon', 'carignangrenache', 'tannatsyrah',
    'rosado', 'provence red blend', 'marselan', 'merlottannat', 'tannatcabernet', 'tannatmerlot',
    'tannatcabernet franc'
]

white_wines3 = [
    'rieslingchardonnay', 'sauvignon gris', 'edelzwicker', 'chardonnayriesling', 'touriga nacional blend',
    'moscato giallo', 'pinot blancviognier', 'chardonel', 'cayuga', 'roussannegrenache blanc', 'viogniermarsanne',
    'pinot grigiosauvignon blanc', 'viogniergrenache blanc', 'valvin muscat', 'melon', 'chancellor',
    'pinot blancchardonnay', 'chardonnayalbario', 'silvaner', 'viogniervaldigui', 'prosecco', 'chardonnaypinot blanc',
    'muscat dalexandrie', 'alvarinho', 'alsace white blend', 'ugni blanccolombard', 'savagnin', 'sylvaner',
    'chenin blancchardonnay', 'provence white blend', 'colombardsauvignon blanc', 'gros and petit manseng',
    'muscadelle', 'gros manseng', 'chardonnaysauvignon', 'sauvignon', 'sauvignonsmillon', 'sauvignon blancchardonnay',
    'chasselas', "loin de l'oeil", 'chardonnaysauvignon blanc', 'colombardugni blanc', 'chardonnaypinot gris',
    'sacy', 'mansois', 'sciaccerellu', 'fer servadou', 'romorantin', 'braucol', 'rolle'
]

rose_wines3 = []

sparkling_wines3 = []

dessert_wines3 = [ 
    'madeira blend', 'muscat dalexandrie', 'black monukka'
]


print(len(red_wines3))
print(len(white_wines3))
print(len(rose_wines3))
print(len(sparkling_wines3))
print(len(dessert_wines3))
print(len(red_wines3)+len(white_wines3)+len(rose_wines3)+len(sparkling_wines3)+len(dessert_wines3))
# Out:
# 26
# 50
# 0
# 0
# 3
# 79

# %%
wines4 = ['carignansyrah',
 'syrahcarignan',
 'merlotgrenache',
 'malbeccabernet franc',
 'grenache gris',
 'lambrusco di sorbara',
 'lambrusco',
 'lambrusco grasparossa',
 'nero di troia',
 'lambrusco salamino',
 'pallagrello nero',
 'folle blanche',
 'catarratto',
 'inzolia',
 'vernaccia',
 'garganega',
 'glera',
 'verdicchio',
 'carricante',
 'pri blanc',
 'pecorino',
 'grolleau',
 'muscadel',
 'tokay pinot gris',
 'petit courbu',
 'ondenc',
 'frappato',
 'monica',
 'grillo',
 'prugnolo gentile',
 'pinot bianco',
 'friulano',
 'nerello mascalese',
 'cannonau',
 'verduzzo',
 'corvina rondinella molinara',
 'insolia',
 'zibibbo',
 'turbiana',
 'ruch',
 'cesanese',
 'pugnitello',
 'tocai',
 'albanello',
 'nosiola',
 'perricone',
 'albana',
 'grechetto',
 'carignano',
 'torbato',
 'pallagrello',
 'aleatico',
 'magliocco',
 'nascetta',
 'schiava',
 'moscadello',
 'durella',
 'passerina',
 'uva di troia',
 'raboso',
 'marzemino',
 'trebbiano spoletino',
 'freisa',
 'brachetto',
 'pallagrello bianco',
 'veltliner',
 'gaglioppo',
 'piedirosso',
 'susumaniello',
 'vitovska',
 'picolit',
 'nerello cappuccio',
 'corvina',
 'cesanese daffile',
 'verduzzo friulano',
 'coda di volpe',
 'manzoni',
 'timorasso',
 'pigato',
 'grignolino',
 'groppello',
 'pignoletto',
 'ciliegiolo',
 'mantonico',
 'alicante',
 'grecanico',
 'casavecchia',
 'nuragus',
 'incrocio manzoni',
 'cococciola',
 'bombino bianco',
 'vespolina',
 'rebo',
 'traminer',
 'malvasia di candia',
 'molinara',
 'malvasia istriana',
 'erbaluce',
 'vespaiolo',
 'biancolella']

# %%
print(len(wines4))
# Out:
# 100

# %%
red_wines4 = [
    'grolleau', 'carignansyrah', 'syrahcarignan', 'merlotgrenache', 'frappato', 'nerello mascalese', 'cannonau',
    'pinot nero', 'sangiovese grosso', 'negroamaro', 'dornfelder', 'cesanese', 'pugnitello', 'lambrusco',
    'ruch', 'lambrusco di sorbara', 'cesanese', 'pugnitello', 'lambrusco grasparossa', 'schiava',
    'raboso', 'marzemino', 'freisa', 'nero di troia', 'brachetto', 'gaglioppo', 'piedirosso', 'susumaniello',
    'nerello cappuccio', 'corvina', 'magliocco', 'alicante', 'vespolina', 'rebo', 'grignolino', 'groppello',
    'ciliegiolo', 'casavecchia', 'uva di troia', 'nero d’avola', 'malbeccabernet franc', 'merlotgrenache'
]

white_wines4 = [
    'folle blanche', 'muscadel', 'tokay pinot gris', 'grenache gris', 'petit courbu', 'ondenc', 'catarratto',
    'inzolia', 'monica', 'grillo', 'vernaccia', 'pinot bianco', 'friulano', 'garganega', 'verduzzo',
    'verdicchio', 'carricante', 'insolia', 'zibibbo', 'turbiana', 'glera', 'moscato giallo', 'malvasia di candia',
    'malvasia istriana', 'erbaluce', 'falanghina', 'ribolla gialla', 'cortese', 'grecanico', 'vermentino',
    'trebbiano', 'viognier', 'sauvignon blanc', 'chardonnay', 'pinot grigio', 'prosecco', 'vermentino',
    'carricante', 'fiano', 'pecorino', 'albanello', 'nosiola', 'perricone', 'albana', 'grechetto', 'torbato',
    'pallagrello bianco', 'trebbiano spoletino', 'arneis', 'pri blanc', 'turbiana', 'garganega', 'vernaccia'
]

rose_wines4 = [
    # Based on common knowledge, no specific wines from the list are exclusively known for rose production.
]

sparkling_wines4 = [
    'lambrusco', 'glera', # Lambrusco and Prosecco (Glera) are known for sparkling wines.
]

dessert_wines4 = [
    # Dessert wines would typically include late harvest, ice wine, or specific sweet varietals.
]

print(len(red_wines4))
print(len(white_wines4))
print(len(rose_wines4))
print(len(sparkling_wines4))
print(len(dessert_wines4))
print(len(red_wines4)+len(white_wines4)+len(rose_wines4)+len(sparkling_wines4)+len(dessert_wines4))
# Out:
# 42
# 53
# 0
# 2
# 0
# 97

# %%
wines5 = ['malvasia nera',
 'canaiolo',
 'bombino nero',
 'bovale',
 'teroldego rotaliano',
 'vermentino nero',
 'franconia',
 'nasco',
 'sirica',
 'colorino',
 'centesimino',
 'tintilia',
 'pignolo',
 'tempranillomerlot',
 'menca',
 'garnacha tintorera',
 'monastrellsyrah',
 'tinta de toro',
 'tinta fina',
 'maturana',
 'tinto fino',
 'tinto del pais',
 'trepat',
 'bobal',
 'prieto picudo',
 'mazuelo',
 'tinta del pais',
 'garnachasyrah',
 'rufete',
 'tempranilloshiraz',
 'carinea',
 'tempranillo blanco',
 'tinto velasco',
 'shirazcabernet sauvignon',
 'carienagarnacha',
 'garnachamonastrell',
 'listn negro',
 'garnacha blend',
 'vidadillo',
 'jaen',
 'garnachatempranillo',
 'shiraztempranillo',
 'monastrellpetit verdot',
 'garnachacabernet',
 'garnachacariena',
 'babosa negro',
 'parraleta',
 'bobalcabernet sauvignon',
 'portuguese red',
 'greco bianco',
 'gragnano',
 'trebbiano di lugana',
 'albarossa',
 'malvar',
 'verdeca',
 'uvalino',
 'moscato rosa',
 'biancale',
 'ansonica',
 'roviello',
 'catalanesca',
 'favorita',
 'moscato di noto',
 'asprinio',
 'caprettone',
 'viura',
 'verdejoviura',
 'xarello',
 'pansa blanca',
 'moscatel',
 'viurachardonnay',
 'godello',
 'pedro ximnez',
 'macabeo',
 'verdil',
 'treixadura',
 'forcall',
 'viuraverdejo',
 'tinta del toro',
 'hondarrabi zuri',
 'doa blanca',
 'verdejosauvignon blanc',
 'malvasiaviura',
 'macabeochardonnay',
 'macabeomoscatel',
 'paralleda',
 'airen',
 'muscat of alexandria',
 'verdosilla',
 'sauvignon blancverdejo',
 'moscatel de alejandra',
 'meseguera',
 'merseguerasauvignon blanc',
 'premsal',
 'picapoll',
 'portuguese white',
 'anto vaz',
 'souso',
 'avesso',
 'tinta mida',
 'moscato rosa',
 'pedro ximnez']

# %%
red_wines5 = [
    'malvasia nera', 'canaiolo', 'bombino nero', 'bovale', 'teroldego rotaliano', 'vermentino nero',
    'franconia', 'nasco', 'sirica', 'colorino', 'centesimino', 'tintilia', 'pignolo', 'tempranillomerlot',
    'menca', 'garnacha tintorera', 'monastrellsyrah', 'tinta de toro', 'tinta fina', 'maturana', 'tinto fino',
    'tinto del pais', 'trepat', 'bobal', 'prieto picudo', 'mazuelo', 'tinta del pais', 'garnachasyrah', 'rufete',
    'tempranilloshiraz', 'carinea', 'tempranillo blanco', 'tinto velasco', 'shirazcabernet sauvignon', 'carienagarnacha',
    'garnachamonastrell', 'listn negro', 'garnacha blend', 'vidadillo', 'jaen', 'garnachatempranillo', 'shiraztempranillo',
    'monastrellpetit verdot', 'garnachacabernet', 'garnachacariena', 'babosa negro', 'parraleta', 'bobalcabernet sauvignon',
    'portuguese red'
]

white_wines5 = [
    'greco bianco', 'gragnano', 'trebbiano di lugana', 'albarossa', 'malvar', 'verdeca', 'uvalino', 'biancale', 'ansonica', 'roviello', 'catalanesca', 'favorita', 'moscato di noto', 'asprinio', 'caprettone',
    'viura', 'verdejoviura', 'xarello', 'pansa blanca', 'moscatel', 'viurachardonnay', 'godello', 'macabeo', 'verdil', 'treixadura', 'forcall', 'viuraverdejo', 'tinta del toro', 'hondarrabi zuri', 'doa blanca',
    'verdejosauvignon blanc', 'malvasiaviura', 'macabeochardonnay', 'macabeomoscatel', 'paralleda', 'airen',
    'muscat of alexandria', 'verdosilla', 'sauvignon blancverdejo', 'moscatel de alejandra', 'meseguera',
    'merseguerasauvignon blanc', 'premsal', 'picapoll', 'portuguese white', 'anto vaz', 'souso', 'avesso', 'tinta mida'
]

rose_wines5 = [
    # No specific varieties in the provided list are exclusively known for rosé production.
]

sparkling_wines5 = []

dessert_wines5 = [
    'moscato rosa', 'pedro ximnez', # Known for sweet, dessert-style wines.
]




print(len(red_wines5))
print(len(white_wines5))
print(len(rose_wines5))
print(len(sparkling_wines5))
print(len(dessert_wines5))
print(len(red_wines5)+len(white_wines5)+len(rose_wines5)+len(sparkling_wines5)+len(dessert_wines5))
# Out:
# 49
# 49
# 0
# 0
# 2
# 100

# %%
wines6 = ['baga',
 'aragonez',
 'tinta barroca',
 'castelo',
 'tinta roriz',
 'trincadeira',
 'touriga nacionalcabernet sauvignon',
 'touriga franca',
 'tinta cao',
 'bagatouriga nacional',
 'aragons',
 'tinta francisca',
 'bastardo',
 'tinta negra mole',
 'merlotsyrah',
 'cabernet franccarmenre',
 'carmenrecabernet sauvignon',
 'carmenresyrah',
 'malbeccarmnre',
 'bonarda',
 'malbecpetit verdot',
 'malbeccabernet',
 'cabernet francmalbec',
 'syrahmalbec',
 'malbecbonarda',
 'malbec blend',
 'cabernetmalbec',
 'syrahbonarda',
 'malbectempranillo',
 'shirazmalbec',
 'austrian red blend',
 'durif',
 'shirazmourvdre',
 'frburgunder',
 'sptburgunder',
 'trollinger',
 'bical',
 'cerceal',
 'ferno pires',
 'arinto',
 'encruzado',
 'siria',
 'alfrocheiro',
 'cercial',
 'loureiro',
 'loureiroarinto',
 'cdega do larinho',
 'azal',
 'moscatel grado',
 'viosinho',
 'maria gomes',
 'maria gomesbical',
 'gouveio',
 'bual',
 'rabigato',
 'alvarinhochardonnay',
 'sercial',
 'malvasia fina',
 'jampal',
 'trajadura',
 'pas',
 'muscatel',
 'torontel',
 'weissburgunder',
 'gelber muskateller',
 'st laurent',
 'rotgipfler',
 'zierfandler',
 'welschriesling',
 'roter veltliner',
 'zierfandlerrotgipfler',
 'neuburger',
 'austrian white blend',
 'morillon',
 'rosenmuskateller',
 'grauburgunder',
 'blauburgunder',
 'muskateller',
 'roter traminer',
 'orangetraube',
 'smling',
 'furmint',
 'gelber traminer',
 'chardonnay weissburgunder',
 'rivaner',
 'elbling',
 'schwartzriesling',
 'silvanertraminer',
 'portuguese ros',
 'portuguese sparkling',
 'moscatel roxo',
 'vinho',
 'shirazviognier',
 'shirazgrenache',
 'tokay',
 'shirazcabernet',
 'grenacheshiraz',
 'cabernet sauvignonmerlotshiraz',
 'shirazroussanne',
 'malvasiaviura',
 'sauvignon blancverdejo',
 'garnachamonastrell',
 'verdosilla',
 'muscat of alexandria',
 'portuguese white',
 'avesso',
 'tinta mida']

# %%
red_wines6 = [
    'baga', 'aragonez', 'tinta barroca', 'castelo', 'tinta roriz', 'trincadeira', 
    'touriga nacionalcabernet sauvignon', 'touriga franca', 'tinta cao', 'bagatouriga nacional',
    'aragons', 'tinta francisca', 'bastardo', 'tinta negra mole', 'merlotsyrah',
    'cabernet franccarmenre', 'carmenrecabernet sauvignon', 'carmenresyrah', 'malbeccarmnre',
    'bonarda', 'malbecpetit verdot', 'malbeccabernet', 'cabernet francmalbec', 'syrahmalbec',
    'malbecbonarda', 'malbec blend', 'cabernetmalbec', 'syrahbonarda', 'malbectempranillo', 'shirazmalbec',
    'austrian red blend', 'durif', 'shirazmourvdre', 'frburgunder', 'sptburgunder', 'trollinger'
]

white_wines6 = [
    'bical', 'cerceal', 'ferno pires', 'arinto', 'encruzado', 'siria', 'alfrocheiro',
    'cercial', 'loureiro', 'loureiroarinto', 'cdega do larinho', 'azal', 'moscatel grado', 'viosinho',
    'maria gomes', 'maria gomesbical', 'gouveio', 'bual', 'rabigato', 'alvarinhochardonnay', 
    'sercial', 'malvasia fina', 'jampal', 'trajadura', 'pas', 'muscatel', 'torontel', 
    'weissburgunder', 'gelber muskateller', 'st laurent', 'rotgipfler', 'zierfandler', 'welschriesling',
    'roter veltliner', 'zierfandlerrotgipfler', 'neuburger', 'austrian white blend', 'morillon',
    'rosenmuskateller', 'grauburgunder', 'blauburgunder', 'muskateller', 'roter traminer', 'orangetraube',
    'smling', 'furmint', 'gelber traminer', 'chardonnay weissburgunder', 'rivaner', 'elbling', 
    'schwartzriesling', 'silvanertraminer'
]

rose_wines6 = [
    'portuguese ros' # Assuming it's a rosé based on the name.
]

sparkling_wines6 = [
    'portuguese sparkling'
]

dessert_wines6 = [
    'moscatel roxo'
]

print(len(red_wines6))
print(len(white_wines6))
print(len(rose_wines6))
print(len(sparkling_wines6))
print(len(dessert_wines6))
print(len(red_wines6)+len(white_wines6)+len(rose_wines6)+len(sparkling_wines6)+len(dessert_wines6))
# Out:
# 36
# 52
# 1
# 1
# 1
# 91

# %%
wines7 = [
    'pinotagemerlot', 'merlotshiraz', 'merlotargaman', 'argaman', 'agiorgitiko', 'xinomavro', 
    'mavrodaphne', 'mavroudi', 'mandilaria', 'mavrotragano', 'mandilaria', 'kotsifali', 'mavrokalavryta',
    'chenin blancsauvignon blanc', 'marawi', 'assyrtico', 'vilana', 'roditis', 'malagousia', 
    'assyrtiko', 'moschofilero', 'thrapsathiri', 'savatiano', 'plyto', 'sideritis', 'aidani', 
    'malagouziachardonnay', 'robola', 'malagouzia', 'sauvignon blancassyrtiko', 'roditismoschofilero', 
    'dafni', 'athiri',
    'moschofilerochardonnay',
    'cabernet sauvignon grenache'
]

# %%
len(wines7)
# Out:
# 35

# %%
red_wines7 = [
    'pinotagemerlot', 'merlotshiraz', 'merlotargaman', 'argaman', 'agiorgitiko', 'xinomavro', 
    'mavrodaphne', 'mavroudi', 'mandilaria', 'mavrotragano', 'mandilaria', 'kotsifali', 'mavrokalavryta'
]

white_wines7 = [
    'chenin blancsauvignon blanc', 'marawi', 'assyrtico', 'vilana', 'roditis', 'malagousia', 
    'assyrtiko', 'moschofilero', 'thrapsathiri', 'savatiano', 'plyto', 'sideritis', 'aidani', 
    'malagouziachardonnay', 'robola', 'malagouzia', 'sauvignon blancassyrtiko', 'roditismoschofilero', 
    'dafni', 'athiri'
]

rose_wines7 = [
    # The provided list doesn't clearly specify any varieties exclusively known for rosé production.
]

sparkling_wines7 = [
    # No specific varieties in the provided list are known exclusively for sparkling wine production.
]

dessert_wines7 = [
    'moschofilerochardonnay', # Assuming based on the combination, though traditionally Moschofilero isn't a dessert wine.
    # Mavrodaphne could also be considered here for its use in sweet, fortified wines.
]


print(len(red_wines7))
print(len(white_wines7))
print(len(rose_wines7))
print(len(sparkling_wines7))
print(len(dessert_wines7))
print(len(red_wines7)+len(white_wines7)+len(rose_wines7)+len(sparkling_wines7)+len(dessert_wines7))
# Out:
# 13
# 20
# 0
# 0
# 1
# 34

# %% [markdown]
# ''' Now we are going to concanate the different Splits into the main wines  '''

# %%
print(len(processed_wine_list))
# Out:
# 634

# %%
m_red_wines = red_wines1 + red_wines2 + red_wines3 + red_wines4 + red_wines5 + red_wines6 + red_wines7
m_white_wines = white_wines1 + white_wines2 + white_wines3 + white_wines4 + white_wines5 + white_wines6 + white_wines7
m_rose_wines = rose_wines1 + rose_wines2 + rose_wines3 + rose_wines4 + rose_wines5 + rose_wines6 + rose_wines7
m_sparkling_wines = sparkling_wines1 + sparkling_wines2 + sparkling_wines3 + sparkling_wines4 + sparkling_wines5 + sparkling_wines6 + sparkling_wines7
m_dessert_wines = dessert_wines1 + dessert_wines2 + dessert_wines3 + dessert_wines4 + dessert_wines5 + dessert_wines6 + dessert_wines7

# %%
print(len(m_red_wines))
print(len(m_white_wines))
print(len(m_rose_wines))
print(len(m_sparkling_wines))
print(len(m_dessert_wines))

total_wines_duplicates = len(m_red_wines) + len(m_white_wines) + len(m_rose_wines) + len(m_sparkling_wines) + len(m_dessert_wines)

# Print the total
print(total_wines_duplicates)
# Out:
# 247
# 294
# 3
# 5
# 18
# 567

# %%
most_red_wines = list(set(m_red_wines))
most_white_wines = list(set(m_white_wines))
most_rose_wines = list(set(m_rose_wines))
most_sparkling_wines = list(set(m_sparkling_wines))
most_dessert_wines = list(set(m_dessert_wines))

# %%
print(len(most_red_wines))
print(len(most_white_wines))
print(len(most_rose_wines))
print(len(most_sparkling_wines))
print(len(most_dessert_wines))

total_wines = len(most_red_wines) + len(most_white_wines) + len(most_rose_wines) + len(most_sparkling_wines) + len(most_dessert_wines)

print(total_wines)
# Out:
# 238
# 278
# 3
# 5
# 18
# 542

# %%
634 - 542 ##### WE HAVE 92 MISSING WINES, Let see if for loops work, fingers crossed
# Out:
# 92

# %%
most_wines = most_red_wines + most_white_wines + most_rose_wines + most_sparkling_wines + most_dessert_wines

# %%
missing_wines = []

for wine in processed_wine_list:
    if wine in most_wines:
        pass
    else:
        missing_wines.append(wine)
        
print(len(missing_wines))
# Out:
# 127

# %%
# We get 127 wines missing, when there should be only 92, meaning a difference of 35 wines due to the foor lopp problem!" But It's doable

# %%
missing_wines
# Out:
# ['albario',
#  'rhnestyle red blend',
#  'fum blanc',
#  'gewrztraminer',
#  'ros',
#  'grner veltliner',
#  'nero davola',
#  'muscat blanc  petits grains',
#  'charbono',
#  'rhnestyle white blend',
#  'mourvdre',
#  'pinot meunier',
#  'muskat ottonel',
#  'syrahviognier',
#  'carmenre',
#  'teroldego',
#  'traminette',
#  'chambourcin',
#  'smillon',
#  'semillonsauvignon blanc',
#  'garnacha',
#  'grenachesyrah',
#  'seyval blanc',
#  'muscat canelli',
#  'sauvignon blancsemillon',
#  'bordeauxstyle white blend',
#  'vidal blanc',
#  'gewrztraminerriesling',
#  'lemberger',
#  'blanc du bois',
#  'colombard',
#  'auxerrois',
#  'muskat',
#  'cabernet francmerlot',
#  'malvasia',
#  'tocai friulano',
#  'chardonnaysemillon',
#  'norton',
#  'cinsault',
#  'symphony',
#  'black muscat',
#  'valdigui',
#  'syrahmourvdre',
#  'blaufrnkisch',
#  'mourvdresyrah',
#  'tempranillo blend',
#  'cabernet sauvignonmerlot',
#  'aligot',
#  'cabernet sauvignoncabernet franc',
#  'counoise',
# ...

# %%
missing_wines1 = missing_wines[0:67]
missing_wines2 = missing_wines[67:]

# %%
missing_wines1
# Out:
# ['albario',
#  'rhnestyle red blend',
#  'fum blanc',
#  'gewrztraminer',
#  'ros',
#  'grner veltliner',
#  'nero davola',
#  'muscat blanc  petits grains',
#  'charbono',
#  'rhnestyle white blend',
#  'mourvdre',
#  'pinot meunier',
#  'muskat ottonel',
#  'syrahviognier',
#  'carmenre',
#  'teroldego',
#  'traminette',
#  'chambourcin',
#  'smillon',
#  'semillonsauvignon blanc',
#  'garnacha',
#  'grenachesyrah',
#  'seyval blanc',
#  'muscat canelli',
#  'sauvignon blancsemillon',
#  'bordeauxstyle white blend',
#  'vidal blanc',
#  'gewrztraminerriesling',
#  'lemberger',
#  'blanc du bois',
#  'colombard',
#  'auxerrois',
#  'muskat',
#  'cabernet francmerlot',
#  'malvasia',
#  'tocai friulano',
#  'chardonnaysemillon',
#  'norton',
#  'cinsault',
#  'symphony',
#  'black muscat',
#  'valdigui',
#  'syrahmourvdre',
#  'blaufrnkisch',
#  'mourvdresyrah',
#  'tempranillo blend',
#  'cabernet sauvignonmerlot',
#  'aligot',
#  'cabernet sauvignoncabernet franc',
#  'counoise',
# ...

# %%
missing_wines2
# Out:
# ['saperavi',
#  'tinta amarela',
#  'chelois',
#  'apple',
#  'st vincent',
#  'kerner',
#  'tinta madeira',
#  'pinot noirgamay',
#  'altesse',
#  'carcajolu',
#  'jacqure',
#  'mauzac',
#  'duras',
#  'loin de loeil',
#  'prunelard',
#  'gros plant',
#  'poulsard',
#  'trousseau',
#  'nielluciu',
#  'prugnolo gentile',
#  'corvina rondinella molinara',
#  'tocai',
#  'carignano',
#  'pallagrello',
#  'aleatico',
#  'nascetta',
#  'moscadello',
#  'durella',
#  'passerina',
#  'veltliner',
#  'vitovska',
#  'picolit',
#  'cesanese daffile',
#  'verduzzo friulano',
#  'coda di volpe',
#  'manzoni',
#  'timorasso',
#  'pigato',
#  'pignoletto',
#  'mantonico',
#  'nuragus',
#  'incrocio manzoni',
#  'lambrusco salamino',
#  'cococciola',
#  'bombino bianco',
#  'pallagrello nero',
#  'traminer',
#  'molinara',
#  'vespaiolo',
#  'biancolella',
#  'vinho',
#  'shirazviognier',
#  'shirazgrenache',
#  'tokay',
#  'shirazcabernet',
#  'grenacheshiraz',
# ...

# %%
missing_reds1 = [
    'rhnestyle red blend', 'mourvdre', 'syrahviognier', 'carmenre', 'tempranillo blend',
    'cabernet sauvignonmerlot', 'grenachesyrah', 'syrahmourvdre', 'mourvdresyrah',
    'cabernet sauvignoncabernet franc', 'grenachemourvdre', 'cabernet sauvignoncarmenre',
    'cabernet pfeffer', 'cabernet francmerlot', 'cinsault', 'counoise', 'blaufrnkisch',
    'malbeccabernet sauvignon', 'charbono', 'norton', 'chambourcin'
]

missing_whites1 = [ 
    'albario', 'fum blanc', 'gewrztraminer', 'grner veltliner', 'nero davola',
    'muscat blanc  petits grains', 'rhnestyle white blend', 'pinot meunier',
    'muskat ottonel', 'teroldego', 'traminette', 'chardonnaysemillon',
    'smillon', 'semillonsauvignon blanc', 'bordeauxstyle white blend', 'vidal blanc',
    'gewrztraminerriesling', 'lemberger', 'blanc du bois', 'colombard', 'auxerrois',
    'muskat', 'malvasia', 'tocai friulano', 'viogniergewrztraminer', 'mllerthurgau',
    'alvarelho', 'pinot blancpinot noir', 'pinot grisgewrztraminer', 'sauvignon musqu', 'garnacha',
    'aligot', 'sauvignon blancsemillon', 'seyval blanc',  'muscat canelli',
]

missing_rose1 = ['ros', 'marquette']

missing_sparkling1 = ['symphony']

missing_dessert1 = ['black muscat', 'valdigui', 'mission', 'torronts', 'souzao', 'muscadine', 'jacquez', 'morio muskat']

# %%
missing_reds2 = [
    'saperavi', 'tinta amarela', 'chelois', 'st vincent', 'tinta madeira',
    'pinot noirgamay', 'carcajolu', 'mauzac', 'duras', 'loin de loeil',
    'prunelard', 'poulsard', 'trousseau', 'nielluciu', 'prugnolo gentile',
    'corvina rondinella molinara', 'carignano', 'pallagrello', 'aleatico',
    'nascetta', 'durella', 'passerina', 'cesanese daffile',
    'coda di volpe', 'timorasso', 'pigato', 'pallagrello nero', 'traminer',
    'molinara', 'shirazviognier', 'shirazgrenache', 'shirazcabernet',
    'grenacheshiraz', 'cabernet sauvignonmerlotshiraz', 'shirazroussanne', 'cabernet sauvignon grenache',
    'vinho',  'incrocio manzoni',
]

missing_whites2 = [
    'apple', 'kerner', 'altesse', 'jacqure', 'gros plant',
    'vitovska', 'picolit', 'verduzzo friulano', 'manzoni', 'vespaiolo',
    'biancolella', 'tokay', 'rieslaner', 'tocai','bombino bianco', 'nuragus',  'cococciola',
    'pignoletto',  'mantonico'
]

missing_rose2 = [] 

missing_sparkling2 = ['veltliner', 'lambrusco salamino']  

missing_dessert2 = ['moscadello']

# %% [markdown]
# ''' Ok, Now we have our Missing wines, from 127, the list says 92, now we have to concatenate the values the 127 values to their respectilvy categories, and drop duplicates'
#
# ''' Before that we have to concatonate Missing Wines 1 and 2 ; Step by Step Just so its easier to undersstand'''

# %%
missing_reds_d = missing_reds1 + missing_reds2
missing_whites_d = missing_whites1 + missing_whites2
missing_rose_d = missing_rose1 + missing_rose2
missing_sparkling_d = missing_sparkling1 + missing_sparkling2
missing_dessert_d = missing_dessert1 + missing_dessert2

# %%
print(len(missing_reds_d))
print(len(missing_whites_d))
print(len(missing_rose_d))
print(len(missing_sparkling_d))
print(len(missing_dessert_d))
# Out:
# 59
# 54
# 2
# 3
# 9

# %%
59+54+2+3+9 # All here!
# Out:
# 127

# %% [markdown]
# Now let's check for duplicates

# %%
missing_reds = list(set(missing_reds_d))
missing_whites = list(set(missing_whites_d))
missing_rose = list(set(missing_rose_d))
missing_sparkling = list(set( missing_sparkling_d))
missing_dessert = list(set(missing_dessert_d))

# %%
print(len(missing_reds))
print(len(missing_whites))
print(len(missing_rose))
print(len(missing_sparkling))
print(len(missing_dessert))
# Out:
# 59
# 54
# 2
# 3
# 9

# %% [markdown]
#  Same Number! No Duplicates!!

# %%
all_red_wines_d = most_red_wines + missing_reds
all_white_wines_d =  most_white_wines + missing_whites
all_rose_wines_d = most_rose_wines + missing_rose
all_sparkling_wines_d = most_sparkling_wines + missing_sparkling
all_dessert_wines_d = most_dessert_wines + missing_dessert

# %%
print(len(all_red_wines_d))
print(len(all_white_wines_d))
print(len(all_rose_wines_d))
print(len(all_sparkling_wines_d))
print(len(all_dessert_wines_d))

t_len = len(all_red_wines_d) + len(all_white_wines_d) + len(all_rose_wines_d) + len(all_sparking_wines_d) + len(all_dessert_wines_d)

print(t_len)
# Out:
# 297
# 332
# 5
# 8
# 27
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [41], line 7
#       4 print(len(all_sparkling_wines_d))
#       5 print(len(all_dessert_wines_d))
# ----> 7 t_len = len(all_red_wines_d) + len(all_white_wines_d) + len(all_rose_wines_d) + len(all_sparking_wines_d) + len(all_dessert_wines_d)
#       9 print(t_len)
#
# NameError: name 'all_sparking_wines_d' is not defined

# %% [markdown]
# We have 669 values for wines, which is more than 634! Which means we have around 35 duplicates (this is due to the for loop problem, and the mismatch spelling)  Which is the same 35 as before!

# %%
#all_red_wines = list(set(all_red_wines_d))
#all_white_wines = list(set(all_white_wines_d))
#all_rose_wines = list(set(all_rose_wines_d))
#all_sparkling_wines = list(set(all_sparkling_wines_d))
#all_dessert_wines = list(set(all_dessert_wines_d))

# %%
#print(len(all_red_wines))
#print(len(all_white_wines))
#print(len(all_rose_wines))
#print(len(all_sparkling_wines))
#print(len(all_dessert_wines))

#total_wines = all_red_wines + all_white_wines + all_rose_wines + all_sparkling_wines + all_dessert_wines

#print(len(total_wines))

# %% [markdown]
# The Drop duplicates isn't working / Again different spelling

# %%
#sort_total_wines = sorted(total_wines)

# %%
#sort_total_wines

# %%
#sort_total_wines_cleaned_d = clean_strings(sort_total_wines)

# %%
#final_wines = list(set(sort_total_wines_cleaned_d))

# %%
#len(final_wines)

# %% [markdown]
# We got an extra 5 Wines, When we sort and clean all of them together (In reality, we would like to clean each different categories)

# %%
all_red_wines_nc = clean_strings(all_red_wines_d)
all_white_wines_nc = clean_strings(all_white_wines_d)
all_rose_wines_nc = clean_strings(all_rose_wines_d)
all_sparkling_wines_nc = clean_strings(all_sparkling_wines_d)
all_dessert_wines_nc = clean_strings(all_dessert_wines_d)

# %%
all_red_wines_nc_s = sorted(all_red_wines_nc)
all_white_wines_nc_s = sorted(all_white_wines_nc)
all_rose_wines_nc_s = sorted(all_rose_wines_nc)
all_sparkling_wines_nc_s = sorted(all_sparkling_wines_nc)
all_dessert_wines_nc_s = sorted(all_dessert_wines_nc)

# %%
all_red_wines = list(set(all_red_wines_nc_s))
all_white_wines = list(set(all_white_wines_nc_s))
all_rose_wines = list(set(all_rose_wines_nc_s))
all_sparkling_wines = list(set(all_sparkling_wines_nc_s))
all_dessert_wines = list(set(all_dessert_wines_nc_s))

# %%
print(len(all_red_wines))
print(len(all_white_wines))
print(len(all_rose_wines))
print(len(all_sparkling_wines))
print(len(all_dessert_wines))

total_wines = all_red_wines + all_white_wines + all_rose_wines + all_sparkling_wines + all_dessert_wines

print(len(total_wines))
# Out:
# 289
# 322
# 4
# 8
# 27
# 650
