# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import requests

import time

# %% [markdown]
# # Importing the data

# %%
df = pd.read_csv('winemag-data-130k-v2.csv')

# %%
df.head()
# Out:
#    id   country                                        description  \
# 0   0     Italy  Aromas include tropical fruit, broom, brimston...
# 1   1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2   2        US  Tart and snappy, the flavors of lime flesh and...
# 3   3        US  Pineapple rind, lemon pith and orange blossom ...
# 4   4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# # Cleaning the data

# %%
# Dropping useless columns: 'id', 'taster_name', 'taster_twitter_handle'
df.drop(columns = ['id', 'taster_name', 'taster_twitter_handle'], inplace = True)

df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2  \
# 0                 Etna                NaN
# 1                  NaN                NaN
# 2    Willamette Valley  Willamette Valley
# 3  Lake Michigan Shore                NaN
# 4    Willamette Valley  Willamette Valley
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %%
# Checking for null values in region_1 and region_2

print(f"There are {df['region_1'].isna().sum()} null values for region_1")
print(f"There are {df['region_2'].isna().sum()} null values for region_2")
# Out:
# There are 21247 null values for region_1
# There are 79460 null values for region_2

# %%
#Replacing region_1 and region_2 NaN values with empty strings

df.fillna({'region_1': ''}, inplace = True)
df.fillna({'region_2': ''}, inplace = True)

# %%
# Merging region_1 and region_2 columns into a new region column (and dropping the former)

new_col = df['region_1']+', '+df['region_2']

df.insert(loc = 6, column = 'region', value = new_col)

df.drop(columns = ['region_1', 'region_2'], inplace = True)

df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                                  region  \
# 0                                Etna,
# 1                                    ,
# 2  Willamette Valley, Willamette Valley
# 3                 Lake Michigan Shore,
# 4  Willamette Valley, Willamette Valley
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %%
# Replacing null region values with empty strings

df['region'].replace(', ', '', inplace = True)

df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                                  region  \
# 0                                Etna,
# 1
# 2  Willamette Valley, Willamette Valley
# 3                 Lake Michigan Shore,
# 4  Willamette Valley, Willamette Valley
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %%
# Checking for null values in the designation column

print(f"There are {df['designation'].isna().sum()} null values in the designation column")
print(f"This accounts for {round(100*df['designation'].isna().sum()/len(df), 2)}% of our data")
print('I suggest dropping this column')
# Out:
# There are 37465 null values in the designation column
# This accounts for 28.83% of our data
# I suggest dropping this column

# %%
# Dropping the designation column

df.drop(columns = ['designation'], inplace = True)

df.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#             province                                region  \
# 0  Sicily & Sardinia                                Etna,
# 1              Douro
# 2             Oregon  Willamette Valley, Willamette Valley
# 3           Michigan                 Lake Michigan Shore,
# 4             Oregon  Willamette Valley, Willamette Valley
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %% [markdown]
# # Inspecting the country data

# %%
df['country'].value_counts(dropna = False)
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# NaN                          63
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# Peru                         16
# Ukraine                      14
# Macedonia                    12
# Czech Republic               12
# Serbia                       12
# Cyprus                       11
# India                         9
# Switzerland                   7
# Luxembourg                    6
# Bosnia and Herzegovina        2
# Armenia                       2
# Slovakia                      1
# China                         1
# Egypt                         1
# Name: country, dtype: int64

# %%
print(f"There are {len(df['country'].unique())} countries in total")
# Out:
# There are 44 countries in total

# %%
top_15_percent = round(100*df['country'].value_counts(dropna = False)[:15].sum()/len(df), 2)

print(f"The top 15 countries in the dataset represent {top_15_percent}% of the wines\n")

print('The top 15 countries are:')
for i in range(15):
  print(f"{i+1} - {df['country'].value_counts(dropna = False).index[i]}")
# Out:
# The top 15 countries in the dataset represent 98.97% of the wines
#
# The top 15 countries are:
# 1 - US
# 2 - France
# 3 - Italy
# 4 - Spain
# 5 - Portugal
# 6 - Chile
# 7 - Argentina
# 8 - Austria
# 9 - Australia
# 10 - Germany
# 11 - New Zealand
# 12 - South Africa
# 13 - Israel
# 14 - Greece
# 15 - Canada

# %%
# Using only wines from the top 15 countries
top_15_countries = list(df['country'].value_counts()[:15].index)

indices = []

for country in top_15_countries:
  idx = list(df[df['country'] == country].index)
  indices += idx

df = df.loc[indices]

# %%
# Plotting distribution of wines from the top 15 countries
names = ['USA', 'FRA', 'ITA', 'ESP', 'PRT', 'CHL', 'ARG', 'AUT', 'AUS', 'DEU', 'NZL', 'ZAF', 'ISR', 'GRC', 'CAN']

sns.barplot(x = names,
            y = 100*df['country'].value_counts()/len(df))

plt.title('Proportion of wines by country')
plt.ylabel('Proportion of wines (%)')
plt.xlabel('Country');

# %%
print(f'The US is overrepresented in the dataset, accounting for {round(100*df["country"].value_counts()[0]/len(df), 2)}% of the wines')
# Out:
# The US is overrepresented in the dataset, accounting for 42.37% of the wines

# %% [markdown]
# Since the US wines are over-represented, we want to cut these down. We can start by looking at the distibution of scores for US wines, and taking only the top 50% best-scoring US wines

# %%
# Looking at the distribution of scores for US wines

sns.histplot(df[df['country'] == 'US']['points'],
             kde = True,
             stat = 'proportion',
             bins = 20)

plt.ylabel('Proportion (%)')
plt.title('Distribution of scores for US wines');

# %%
# Finding the 60th percentile for US wine scores
df[df['country'] == 'US']['points'].quantile(0.6)
# Out:
# 90.0

# %%
# Removing the lowest-scoring 60% of US wines
worst_US_wines_indices = list(df[df['country'] == 'US'][df['points'] < 90.0].index)

df.drop(index = worst_US_wines_indices, inplace = True)
# Out:
# /var/folders/fz/jr8f8xs121q4rlyl2rcz0tqh0000gn/T/ipykernel_16378/1352491258.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   worst_US_wines_indices = list(df[df['country'] == 'US'][df['points'] < 90.0].index)

# %%
# Looking at the new distribution of wines by country

sns.barplot(x = names,
            y = 100*df['country'].value_counts()/len(df))

plt.xlabel('Country')
plt.ylabel('Proportion of wines (%)')
plt.title('Proportion of wines by country');

# %%
print(f"We now have {len(df)} wines in the dataset")
# Out:
# We now have 96453 wines in the dataset

# %% [markdown]
# Now we can see that US, French, and Italian wines are over-represented, we can take only the remaining 50% best scoring of these wines

# %%
# Finding the median scores for each of these countries

US_med = df[df['country'] == 'US']['points'].quantile(0.5)
FR_med = df[df['country'] == 'France']['points'].quantile(0.5)
ITA_med = df[df['country'] == 'Italy']['points'].quantile(0.5)

print(f"Median scores for the US: {US_med},\nFrance: {FR_med},\nItaly: {ITA_med}")
# Out:
# Median scores for the US: 91.0,
# France: 89.0,
# Italy: 88.0

# %%
# Dropping the worst-scoring 50% of these wines

worst_US_wines_indices_new = list(df[df['country'] == 'US'][df['points'] < US_med].index)
worst_FR_wines_indices = list(df[df['country'] == 'France'][df['points'] < FR_med].index)
worst_ITA_wines_indices = list(df[df['country'] == 'Italy'][df['points'] < ITA_med].index)

worst_indices = worst_US_wines_indices_new + worst_FR_wines_indices + worst_ITA_wines_indices

df.drop(index = worst_indices, inplace = True)
# Out:
# /var/folders/fz/jr8f8xs121q4rlyl2rcz0tqh0000gn/T/ipykernel_16378/2597929370.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   worst_US_wines_indices_new = list(df[df['country'] == 'US'][df['points'] < US_med].index)
# /var/folders/fz/jr8f8xs121q4rlyl2rcz0tqh0000gn/T/ipykernel_16378/2597929370.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   worst_FR_wines_indices = list(df[df['country'] == 'France'][df['points'] < FR_med].index)
# /var/folders/fz/jr8f8xs121q4rlyl2rcz0tqh0000gn/T/ipykernel_16378/2597929370.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   worst_ITA_wines_indices = list(df[df['country'] == 'Italy'][df['points'] < ITA_med].index)

# %%
# Looking at the new distribution of wines by country

sns.barplot(x = names,
             y = 100*df['country'].value_counts()/len(df))

plt.xlabel('Country')
plt.ylabel('Proportion of wines (%)')
plt.title('Proportion of wines by country');

# %%
print(f"We now have {len(df)} wines in the dataset")
# Out:
# We now have 71459 wines in the dataset

# %% [markdown]
# # Inspecting the prices

# %%
print(f"{round(100*df['price'].isna().sum()/len(df), 2)}% of wines have no price")
# Out:
# 8.11% of wines have no price

# %%
# Dropping wines with no prices

print(f"Before dropping null prices, we have {len(df)} wines")

df.dropna(subset = ['price'], inplace = True)

print(f"After dropping null prices, we have {len(df)} wines")
# Out:
# Before dropping null prices, we have 71459 wines
# After dropping null prices, we have 65663 wines

# %%
# Looking at the distribution of wine prices
df['price'].describe()
# Out:
# count    65663.000000
# mean        41.865663
# std         50.687930
# min          4.000000
# 25%         18.000000
# 50%         30.000000
# 75%         50.000000
# max       2500.000000
# Name: price, dtype: float64

# %%
print(f"99% of wines are below ${df['price'].quantile(0.985)}")
# Out:
# 99% of wines are below $169.0

# %%
# Dropping the top 1.5% most expensive wines

df = df[df['price'] <= 169.0]

# %%
# Looking at the new price distribution

sns.histplot(data = df,
             x = 'price',
             bins = 100,
             kde = True)

plt.axvline(df['price'].mean(),
            color = 'red',
            label = 'mean')

plt.axvline(df['price'].quantile(0.25),
            color = 'orange',
            label = 'Q1, Q3')
plt.axvline(df['price'].quantile(0.75),
            color = 'orange')

plt.legend();

# %% [markdown]
# # Inspecting wine varieties

# %%
print(f"We have {len(df['variety'].unique())} unique varieties of wine")
print(f"{df['variety'].isna().sum()} wines have no variety")
# Out:
# We have 551 unique varieties of wine
# 1 wines have no variety

# %%
# Dropping wines with null variety
df.dropna(subset = ['variety'], inplace = True)

print(f"We now have {len(df['variety'].unique())} unique varieties of wine")
# Out:
# We now have 550 unique varieties of wine

# %%
 print(f"{(df['variety'].value_counts() == 1).sum()} wines show up only once")
# Out:
# 110 wines show up only once

# %%
print(f"Plotting the distribution of the top {round(100*df['variety'].value_counts()[df['variety'].value_counts() > 150].sum()/len(df), 2)}% of wine varities")

sns.barplot(round(100*df['variety'].value_counts()[df['variety'].value_counts() > 150]/len(df), 2))

plt.xlabel('Variety')
plt.ylabel('Proportion of total wines (%)');
# Out:
# Plotting the distribution of the top 88.36% of wine varities
# /Users/macbook/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print('The top 10 most represented wines are:')

top_10_wines = list(df['variety'].value_counts()[:10].index)

for name in top_10_wines:
    print(f"{top_10_wines.index(name)+1}: {name}")
# Out:
# The top 10 most represented wines are:
# 1: Pinot Noir
# 2: Chardonnay
# 3: Red Blend
# 4: Cabernet Sauvignon
# 5: Riesling
# 6: Sauvignon Blanc
# 7: Bordeaux-style Red Blend
# 8: Portuguese Red
# 9: Syrah
# 10: Malbec

# %% [markdown]
# The top 5 wines are overrepresented, so I'm going to cut them down so that they are roughly in line with the next 5

# %%
# Finding the proportion for the top 5 wines to cut

prop_six = 100*df[df['variety'] == 'Sauvignon Blanc']['points'].count()/len(df)



props = [(100*df[df['variety'] == top_10_wines[:5][i]]['points'].count()/len(df))/(prop_six) for i in range(5)]
quants = [round(1 - (1/props[i]), 2) for i in range(5)]

for i in range(5):
    print(f"Proportion for {top_10_wines[i]}: {quants[i]}")
# Out:
# Proportion for Pinot Noir: 0.63
# Proportion for Chardonnay: 0.53
# Proportion for Red Blend: 0.49
# Proportion for Cabernet Sauvignon: 0.46
# Proportion for Riesling: 0.28

# %%
# Cutting the quantiles to cut

qs = [df[df['variety'] == top_10_wines[i]]['points'].quantile(quants[i]) for i in range(5)]

for i in range(5):
    print(f"{top_10_wines[i]}: {qs[i]}")
# Out:
# Pinot Noir: 92.0
# Chardonnay: 91.0
# Red Blend: 90.0
# Cabernet Sauvignon: 91.0
# Riesling: 89.0

# %%
# Dropping the lowest-scoring wines for each of the top 5 varieties

for i in range(5):
    indices = list(df[df['variety'] == top_10_wines[i]][df['points'] < qs[i]].index)
    df.drop(index = indices, inplace = True)
# Out:
# /var/folders/fz/jr8f8xs121q4rlyl2rcz0tqh0000gn/T/ipykernel_16378/1548620025.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   indices = list(df[df['variety'] == top_10_wines[i]][df['points'] < qs[i]].index)
# /var/folders/fz/jr8f8xs121q4rlyl2rcz0tqh0000gn/T/ipykernel_16378/1548620025.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   indices = list(df[df['variety'] == top_10_wines[i]][df['points'] < qs[i]].index)
# /var/folders/fz/jr8f8xs121q4rlyl2rcz0tqh0000gn/T/ipykernel_16378/1548620025.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   indices = list(df[df['variety'] == top_10_wines[i]][df['points'] < qs[i]].index)
# /var/folders/fz/jr8f8xs121q4rlyl2rcz0tqh0000gn/T/ipykernel_16378/1548620025.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   indices = list(df[df['variety'] == top_10_wines[i]][df['points'] < qs[i]].index)
# /var/folders/fz/jr8f8xs121q4rlyl2rcz0tqh0000gn/T/ipykernel_16378/1548620025.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   indices = list(df[df['variety'] == top_10_wines[i]][df['points'] < qs[i]].index)

# %%
# Plotting the new distribution of wines by variety

sns.barplot(round(100*df['variety'].value_counts()[df['variety'].value_counts() > 150]/len(df), 2))

plt.xlabel('Variety')
plt.ylabel('Proportion of total wines (%)');
# Out:
# /Users/macbook/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(f"We now have {len(df)} wines in the dataset")
# Out:
# We now have 55350 wines in the dataset

# %% [markdown]
# # Saving this data

# %%
df.to_csv('../data/really_cleaned_wine_data.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [42], line 1
# ----> 1 df.to_csv('../data/really_cleaned_wine_data.csv', index = False)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/core/generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
#    3557     compression=compression,
#    3558     quoting=quoting,
#    3559     columns=columns,
#    3560     index_label=index_label,
#    3561     mode=mode,
#    3562     chunksize=chunksize,
#    3563     quotechar=quotechar,
#    3564     date_format=date_format,
#    3565     doublequote=doublequote,
#    3566     escapechar=escapechar,
#    3567     storage_options=storage_options,
#    3568 )
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/io/formats/format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/io/formats/csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/io/common.py:694, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     692 # Only for write methods
#     693 if "r" not in mode and is_path:
# --> 694     check_parent_directory(str(handle))
#     696 if compression:
#     697     if compression != "zstd":
#     698         # compression libraries do not like an explicit text-mode
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/io/common.py:568, in check_parent_directory(path)
#     566 parent = Path(path).parent
#     567 if not parent.is_dir():
# --> 568     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '../data'

# %% [markdown]
# # Feature engineering: Adding coordinates

# %%
# Checking that every wine has a region and country

print(f"{df['country'].isna().sum()} wines have no country")
print(f"{df['region'].isna().sum()} wines have no region")
# Out:
# 0 wines have no country
# 0 wines have no region

# %%
df.head()
# Out:
#     country                                        description  points  price  \
# 121      US  The vineyard is one of the better Chardonnay s...      92   36.0
# 122      US  Defines Rockpile Zinfandel in intensity of fru...      92   39.0
# 124      US  This sophisticated wine is mostly Cabernet Sau...      92   45.0
# 134      US  Give this young Cab time in the cellar to come...      91   78.0
# 144      US  Thick and brooding, this dark, sweetly tannic ...      91   85.0
#
#        province                          region  \
# 121  California        Alexander Valley, Sonoma
# 122  California                Rockpile, Sonoma
# 124  California               Napa Valley, Napa
# 134  California               Napa Valley, Napa
# 144  California  Spring Mountain District, Napa
#
#                                                  title             variety  \
# 121  Matrix 2007 Stuhlmuller Vineyard Chardonnay (A...          Chardonnay
# 122  Mauritson 2007 Rockpile Cemetary Vineyard Zinf...           Zinfandel
# 124    Silverado 2006 Cabernet Sauvignon (Napa Valley)  Cabernet Sauvignon
# 134  Clark-Clauden 2007 Cabernet Sauvignon (Napa Va...  Cabernet Sauvignon
# 144  Terra Valentine 2013 K Block Cabernet Sauvigno...  Cabernet Sauvignon
#
#               winery
# 121           Matrix
# 122        Mauritson
# 124        Silverado
# 134    Clark-Clauden
# 144  Terra Valentine

# %%
print(f" There are {len(df['winery'].unique())} unique wineries in the dataset")
# Out:
#  There are 9921 unique wineries in the dataset

# %% [markdown]
# ## Creating a dataframe of wineries with addresses

# %%
# Copying the dataframe to avoid modifying the original
location_df = df[['country', 'province', 'region', 'winery']].copy()

location_df.head()
# Out:
#     country    province                          region           winery
# 121      US  California        Alexander Valley, Sonoma           Matrix
# 122      US  California                Rockpile, Sonoma        Mauritson
# 124      US  California               Napa Valley, Napa        Silverado
# 134      US  California               Napa Valley, Napa    Clark-Clauden
# 144      US  California  Spring Mountain District, Napa  Terra Valentine

# %%
# Creating a new column with the address of the winery by concatenating country, province, region
# Then dropping those columns

location_df['address'] = location_df['region'] + ', ' + location_df['province'] + ', ' + location_df['country']

location_df.drop(columns = ['region', 'province', 'country'], inplace = True)

location_df
# Out:
#                  winery                                         address
# 121              Matrix        Alexander Valley, Sonoma, California, US
# 122           Mauritson                Rockpile, Sonoma, California, US
# 124           Silverado               Napa Valley, Napa, California, US
# 134       Clark-Clauden               Napa Valley, Napa, California, US
# 144     Terra Valentine  Spring Mountain District, Napa, California, US
# ...                 ...                                             ...
# 129054     Le Vieux Pin     Okanagan Valley, , British Columbia, Canada
# 129055     Le Vieux Pin     Okanagan Valley, , British Columbia, Canada
# 129116    Tinhorn Creek     Okanagan Valley, , British Columbia, Canada
# 129528  Henry of Pelham            Niagara Peninsula, , Ontario, Canada
# 129581    Burrowing Owl     Okanagan Valley, , British Columbia, Canada
#
# [55350 rows x 2 columns]

# %% [markdown]
# ## API Calling

# %%
# Setting url and api key for Google Geocoding API

geocoding_url = 'https://maps.googleapis.com/maps/api/geocode/json'
#api_key = 'AIzaSyCVH2zKGYK3xGajLccrrNPrSG3dV19Hfeo'

# %%
# Defining a function to request the geocoding API for an address and returning this as a json file

def get_json(x: str):
  ''' Gets the geocoding json for a specified address string'''
  params = {'address': x,
            'key': api_key}

  result = requests.get(geocoding_url, params = params).json()

  return result

# %%
# Looping over the rows and getting a list of the jsons

output_list = []
counter = 0

start = time.time()

for index, row in location_df.iterrows():
  params = {'address': row['address'],
            'key': api_key}

  result = get_json(row['address'])

  if result['status'] != 'OK':
    print(f"Error on row number {counter} with index {index}. \nError response: {result['status']}")
    end = time.time()
    print(f"This has taken {end - start} seconds")
    break

    counter += 1

  if counter%25 == 0:
    print(f"Row number {counter-1} with index {index} of {len(df)} done. {round(100*(counter)/len(location_df), 2)}% complete")

  output_list.append((result['results'][0]['geometry']['location'], row['winery']))

end = time.time()
print(f"This has taken {end - start}")
# Out:
# Row number -1 with index 121 of 55350 done. 0.0% complete
# Row number -1 with index 122 of 55350 done. 0.0% complete
# Row number -1 with index 124 of 55350 done. 0.0% complete
# Row number -1 with index 134 of 55350 done. 0.0% complete
# Row number -1 with index 144 of 55350 done. 0.0% complete
# Row number -1 with index 146 of 55350 done. 0.0% complete
# Row number -1 with index 147 of 55350 done. 0.0% complete
# Row number -1 with index 149 of 55350 done. 0.0% complete
# Row number -1 with index 150 of 55350 done. 0.0% complete
# Row number -1 with index 153 of 55350 done. 0.0% complete
# Row number -1 with index 155 of 55350 done. 0.0% complete
# Row number -1 with index 161 of 55350 done. 0.0% complete
# Row number -1 with index 162 of 55350 done. 0.0% complete
# Row number -1 with index 167 of 55350 done. 0.0% complete
# Row number -1 with index 168 of 55350 done. 0.0% complete
# Row number -1 with index 281 of 55350 done. 0.0% complete
# Row number -1 with index 283 of 55350 done. 0.0% complete
# Row number -1 with index 286 of 55350 done. 0.0% complete
# Row number -1 with index 289 of 55350 done. 0.0% complete
# Row number -1 with index 352 of 55350 done. 0.0% complete
# Row number -1 with index 355 of 55350 done. 0.0% complete
# Row number -1 with index 364 of 55350 done. 0.0% complete
# Row number -1 with index 455 of 55350 done. 0.0% complete
# Row number -1 with index 456 of 55350 done. 0.0% complete
# Row number -1 with index 457 of 55350 done. 0.0% complete
# Row number -1 with index 460 of 55350 done. 0.0% complete
# Row number -1 with index 461 of 55350 done. 0.0% complete
# Row number -1 with index 467 of 55350 done. 0.0% complete
# Row number -1 with index 475 of 55350 done. 0.0% complete
# Row number -1 with index 476 of 55350 done. 0.0% complete
# Row number -1 with index 509 of 55350 done. 0.0% complete
# Row number -1 with index 510 of 55350 done. 0.0% complete
# Row number -1 with index 513 of 55350 done. 0.0% complete
# Row number -1 with index 519 of 55350 done. 0.0% complete
# Row number -1 with index 520 of 55350 done. 0.0% complete
# Row number -1 with index 521 of 55350 done. 0.0% complete
# Row number -1 with index 524 of 55350 done. 0.0% complete
# Row number -1 with index 525 of 55350 done. 0.0% complete
# Row number -1 with index 531 of 55350 done. 0.0% complete
# Row number -1 with index 534 of 55350 done. 0.0% complete
# Row number -1 with index 536 of 55350 done. 0.0% complete
# Row number -1 with index 537 of 55350 done. 0.0% complete
# Row number -1 with index 539 of 55350 done. 0.0% complete
# Row number -1 with index 540 of 55350 done. 0.0% complete
# Row number -1 with index 541 of 55350 done. 0.0% complete
# Row number -1 with index 543 of 55350 done. 0.0% complete
# Row number -1 with index 544 of 55350 done. 0.0% complete
# Row number -1 with index 545 of 55350 done. 0.0% complete
# Row number -1 with index 546 of 55350 done. 0.0% complete
# Row number -1 with index 547 of 55350 done. 0.0% complete
# Row number -1 with index 548 of 55350 done. 0.0% complete
# Row number -1 with index 550 of 55350 done. 0.0% complete
# Row number -1 with index 551 of 55350 done. 0.0% complete
# Row number -1 with index 555 of 55350 done. 0.0% complete
# Row number -1 with index 557 of 55350 done. 0.0% complete
# Row number -1 with index 558 of 55350 done. 0.0% complete
# Row number -1 with index 559 of 55350 done. 0.0% complete
# Row number -1 with index 560 of 55350 done. 0.0% complete
# Row number -1 with index 561 of 55350 done. 0.0% complete
# Row number -1 with index 562 of 55350 done. 0.0% complete
# Row number -1 with index 563 of 55350 done. 0.0% complete
# Row number -1 with index 564 of 55350 done. 0.0% complete
# Row number -1 with index 565 of 55350 done. 0.0% complete
# Row number -1 with index 566 of 55350 done. 0.0% complete
# Row number -1 with index 568 of 55350 done. 0.0% complete
# Row number -1 with index 629 of 55350 done. 0.0% complete
# Row number -1 with index 630 of 55350 done. 0.0% complete
# Row number -1 with index 634 of 55350 done. 0.0% complete
# Row number -1 with index 640 of 55350 done. 0.0% complete
# Row number -1 with index 641 of 55350 done. 0.0% complete
# Row number -1 with index 643 of 55350 done. 0.0% complete
# Row number -1 with index 644 of 55350 done. 0.0% complete
# Row number -1 with index 645 of 55350 done. 0.0% complete
# Row number -1 with index 649 of 55350 done. 0.0% complete
# Row number -1 with index 653 of 55350 done. 0.0% complete
# Row number -1 with index 655 of 55350 done. 0.0% complete
# Row number -1 with index 656 of 55350 done. 0.0% complete
# Row number -1 with index 688 of 55350 done. 0.0% complete
# Row number -1 with index 689 of 55350 done. 0.0% complete
# Row number -1 with index 691 of 55350 done. 0.0% complete
# Row number -1 with index 693 of 55350 done. 0.0% complete
# Row number -1 with index 698 of 55350 done. 0.0% complete
# Row number -1 with index 709 of 55350 done. 0.0% complete
# Row number -1 with index 711 of 55350 done. 0.0% complete
# Row number -1 with index 771 of 55350 done. 0.0% complete
# Row number -1 with index 774 of 55350 done. 0.0% complete
# Row number -1 with index 775 of 55350 done. 0.0% complete
# Row number -1 with index 778 of 55350 done. 0.0% complete
# Row number -1 with index 782 of 55350 done. 0.0% complete
# Row number -1 with index 783 of 55350 done. 0.0% complete
# Row number -1 with index 1066 of 55350 done. 0.0% complete
# Row number -1 with index 1067 of 55350 done. 0.0% complete
# Row number -1 with index 1068 of 55350 done. 0.0% complete
# Row number -1 with index 1069 of 55350 done. 0.0% complete
# Row number -1 with index 1070 of 55350 done. 0.0% complete
# Row number -1 with index 1075 of 55350 done. 0.0% complete
# Row number -1 with index 1078 of 55350 done. 0.0% complete
# Row number -1 with index 1079 of 55350 done. 0.0% complete
# Row number -1 with index 1080 of 55350 done. 0.0% complete
# Row number -1 with index 1081 of 55350 done. 0.0% complete
# Row number -1 with index 1082 of 55350 done. 0.0% complete
# Row number -1 with index 1083 of 55350 done. 0.0% complete
# Row number -1 with index 1085 of 55350 done. 0.0% complete
# Row number -1 with index 1086 of 55350 done. 0.0% complete
# Row number -1 with index 1087 of 55350 done. 0.0% complete
# Row number -1 with index 1088 of 55350 done. 0.0% complete
# Row number -1 with index 1089 of 55350 done. 0.0% complete
# Row number -1 with index 1091 of 55350 done. 0.0% complete
# Row number -1 with index 1092 of 55350 done. 0.0% complete
# Row number -1 with index 1094 of 55350 done. 0.0% complete
# Row number -1 with index 1209 of 55350 done. 0.0% complete
# Row number -1 with index 1210 of 55350 done. 0.0% complete
# Row number -1 with index 1211 of 55350 done. 0.0% complete
# Row number -1 with index 1212 of 55350 done. 0.0% complete
# Row number -1 with index 1213 of 55350 done. 0.0% complete
# Row number -1 with index 1214 of 55350 done. 0.0% complete
# Row number -1 with index 1216 of 55350 done. 0.0% complete
# Row number -1 with index 1219 of 55350 done. 0.0% complete
# Row number -1 with index 1221 of 55350 done. 0.0% complete
# Row number -1 with index 1222 of 55350 done. 0.0% complete
# Row number -1 with index 1223 of 55350 done. 0.0% complete
# Row number -1 with index 1225 of 55350 done. 0.0% complete
# Row number -1 with index 1226 of 55350 done. 0.0% complete
# Row number -1 with index 1227 of 55350 done. 0.0% complete
# Row number -1 with index 1228 of 55350 done. 0.0% complete
# Row number -1 with index 1230 of 55350 done. 0.0% complete
# Row number -1 with index 1231 of 55350 done. 0.0% complete
# Row number -1 with index 1232 of 55350 done. 0.0% complete
# Row number -1 with index 1233 of 55350 done. 0.0% complete
# Row number -1 with index 1234 of 55350 done. 0.0% complete
# Row number -1 with index 1235 of 55350 done. 0.0% complete
# Row number -1 with index 1236 of 55350 done. 0.0% complete
# Row number -1 with index 1417 of 55350 done. 0.0% complete
# Row number -1 with index 1418 of 55350 done. 0.0% complete
# Row number -1 with index 1419 of 55350 done. 0.0% complete
# Row number -1 with index 1420 of 55350 done. 0.0% complete
# Row number -1 with index 1423 of 55350 done. 0.0% complete
# Row number -1 with index 1424 of 55350 done. 0.0% complete
# Row number -1 with index 1428 of 55350 done. 0.0% complete
# Row number -1 with index 1429 of 55350 done. 0.0% complete
# Row number -1 with index 1430 of 55350 done. 0.0% complete
# Row number -1 with index 1431 of 55350 done. 0.0% complete
# Row number -1 with index 1435 of 55350 done. 0.0% complete
# Row number -1 with index 1436 of 55350 done. 0.0% complete
# Row number -1 with index 1439 of 55350 done. 0.0% complete
# Row number -1 with index 1440 of 55350 done. 0.0% complete
# Row number -1 with index 1443 of 55350 done. 0.0% complete
# Row number -1 with index 1444 of 55350 done. 0.0% complete
# Row number -1 with index 1448 of 55350 done. 0.0% complete
# Row number -1 with index 1455 of 55350 done. 0.0% complete
# Row number -1 with index 1456 of 55350 done. 0.0% complete
# Row number -1 with index 1459 of 55350 done. 0.0% complete
# Row number -1 with index 1461 of 55350 done. 0.0% complete
# Row number -1 with index 1464 of 55350 done. 0.0% complete
# Row number -1 with index 1467 of 55350 done. 0.0% complete
# Row number -1 with index 1468 of 55350 done. 0.0% complete
# Row number -1 with index 1469 of 55350 done. 0.0% complete
# Row number -1 with index 1470 of 55350 done. 0.0% complete
# Row number -1 with index 1472 of 55350 done. 0.0% complete
# Row number -1 with index 1501 of 55350 done. 0.0% complete
# Row number -1 with index 1502 of 55350 done. 0.0% complete
# Row number -1 with index 1504 of 55350 done. 0.0% complete
# Row number -1 with index 1510 of 55350 done. 0.0% complete
# Row number -1 with index 1514 of 55350 done. 0.0% complete
# Row number -1 with index 1515 of 55350 done. 0.0% complete
# Row number -1 with index 1523 of 55350 done. 0.0% complete
# Row number -1 with index 1525 of 55350 done. 0.0% complete
# Row number -1 with index 1556 of 55350 done. 0.0% complete
# Row number -1 with index 1557 of 55350 done. 0.0% complete
# Row number -1 with index 1560 of 55350 done. 0.0% complete
# Row number -1 with index 1565 of 55350 done. 0.0% complete
# Row number -1 with index 1567 of 55350 done. 0.0% complete
# Row number -1 with index 1574 of 55350 done. 0.0% complete
# Row number -1 with index 1577 of 55350 done. 0.0% complete
# Row number -1 with index 1579 of 55350 done. 0.0% complete
# Row number -1 with index 1583 of 55350 done. 0.0% complete
# Row number -1 with index 1584 of 55350 done. 0.0% complete
# Row number -1 with index 1728 of 55350 done. 0.0% complete
# Row number -1 with index 1729 of 55350 done. 0.0% complete
# Row number -1 with index 1730 of 55350 done. 0.0% complete
# Row number -1 with index 1731 of 55350 done. 0.0% complete
# Row number -1 with index 1734 of 55350 done. 0.0% complete
# Row number -1 with index 1735 of 55350 done. 0.0% complete
# Row number -1 with index 1737 of 55350 done. 0.0% complete
# Row number -1 with index 1739 of 55350 done. 0.0% complete
# Row number -1 with index 1741 of 55350 done. 0.0% complete
# Row number -1 with index 1742 of 55350 done. 0.0% complete
# Row number -1 with index 1749 of 55350 done. 0.0% complete
# Row number -1 with index 1780 of 55350 done. 0.0% complete
# Row number -1 with index 1786 of 55350 done. 0.0% complete
# Row number -1 with index 1789 of 55350 done. 0.0% complete
# Row number -1 with index 1792 of 55350 done. 0.0% complete
# Row number -1 with index 1794 of 55350 done. 0.0% complete
# Row number -1 with index 1796 of 55350 done. 0.0% complete
# Row number -1 with index 1866 of 55350 done. 0.0% complete
# Row number -1 with index 1867 of 55350 done. 0.0% complete
# Row number -1 with index 1868 of 55350 done. 0.0% complete
# Row number -1 with index 1873 of 55350 done. 0.0% complete
# Row number -1 with index 1878 of 55350 done. 0.0% complete
# Row number -1 with index 1881 of 55350 done. 0.0% complete
# Row number -1 with index 1882 of 55350 done. 0.0% complete
# Row number -1 with index 1883 of 55350 done. 0.0% complete
# Row number -1 with index 1887 of 55350 done. 0.0% complete
# Row number -1 with index 1888 of 55350 done. 0.0% complete
# Row number -1 with index 2042 of 55350 done. 0.0% complete
# Row number -1 with index 2052 of 55350 done. 0.0% complete
# Row number -1 with index 2053 of 55350 done. 0.0% complete
# Row number -1 with index 2062 of 55350 done. 0.0% complete
# Row number -1 with index 2229 of 55350 done. 0.0% complete
# Row number -1 with index 2231 of 55350 done. 0.0% complete
# Row number -1 with index 2235 of 55350 done. 0.0% complete
# Row number -1 with index 2238 of 55350 done. 0.0% complete
# Row number -1 with index 2241 of 55350 done. 0.0% complete
# Row number -1 with index 2242 of 55350 done. 0.0% complete
# Row number -1 with index 2246 of 55350 done. 0.0% complete
# Row number -1 with index 2250 of 55350 done. 0.0% complete
# Row number -1 with index 2507 of 55350 done. 0.0% complete
# Row number -1 with index 2513 of 55350 done. 0.0% complete
# Row number -1 with index 2515 of 55350 done. 0.0% complete
# Row number -1 with index 2867 of 55350 done. 0.0% complete
# Row number -1 with index 2869 of 55350 done. 0.0% complete
# Row number -1 with index 2874 of 55350 done. 0.0% complete
# Row number -1 with index 2875 of 55350 done. 0.0% complete
# Row number -1 with index 2879 of 55350 done. 0.0% complete
# Row number -1 with index 2880 of 55350 done. 0.0% complete
# Row number -1 with index 2881 of 55350 done. 0.0% complete
# Row number -1 with index 2882 of 55350 done. 0.0% complete
# Row number -1 with index 2885 of 55350 done. 0.0% complete
# Row number -1 with index 2886 of 55350 done. 0.0% complete
# Row number -1 with index 2888 of 55350 done. 0.0% complete
# Row number -1 with index 2984 of 55350 done. 0.0% complete
# Row number -1 with index 2985 of 55350 done. 0.0% complete
# Row number -1 with index 2986 of 55350 done. 0.0% complete
# Row number -1 with index 2989 of 55350 done. 0.0% complete
# Row number -1 with index 2990 of 55350 done. 0.0% complete
# Row number -1 with index 2994 of 55350 done. 0.0% complete
# Row number -1 with index 2995 of 55350 done. 0.0% complete
# Row number -1 with index 3005 of 55350 done. 0.0% complete
# Row number -1 with index 3006 of 55350 done. 0.0% complete
# Row number -1 with index 3007 of 55350 done. 0.0% complete
# Row number -1 with index 3008 of 55350 done. 0.0% complete
# Row number -1 with index 3009 of 55350 done. 0.0% complete
# Row number -1 with index 3013 of 55350 done. 0.0% complete
# Row number -1 with index 3018 of 55350 done. 0.0% complete
# Row number -1 with index 3020 of 55350 done. 0.0% complete
# Row number -1 with index 3022 of 55350 done. 0.0% complete
# Row number -1 with index 3023 of 55350 done. 0.0% complete
# Row number -1 with index 3024 of 55350 done. 0.0% complete
# Row number -1 with index 3026 of 55350 done. 0.0% complete
# Row number -1 with index 3028 of 55350 done. 0.0% complete
# Row number -1 with index 3029 of 55350 done. 0.0% complete
# Row number -1 with index 3030 of 55350 done. 0.0% complete
# Row number -1 with index 3061 of 55350 done. 0.0% complete
# Row number -1 with index 3062 of 55350 done. 0.0% complete
# Row number -1 with index 3064 of 55350 done. 0.0% complete
# Row number -1 with index 3066 of 55350 done. 0.0% complete
# Row number -1 with index 3067 of 55350 done. 0.0% complete
# Row number -1 with index 3070 of 55350 done. 0.0% complete
# Row number -1 with index 3073 of 55350 done. 0.0% complete
# Row number -1 with index 3074 of 55350 done. 0.0% complete
# Row number -1 with index 3075 of 55350 done. 0.0% complete
# Row number -1 with index 3076 of 55350 done. 0.0% complete
# Row number -1 with index 3077 of 55350 done. 0.0% complete
# Row number -1 with index 3078 of 55350 done. 0.0% complete
# Row number -1 with index 3079 of 55350 done. 0.0% complete
# Row number -1 with index 3361 of 55350 done. 0.0% complete
# Row number -1 with index 3364 of 55350 done. 0.0% complete
# Row number -1 with index 3366 of 55350 done. 0.0% complete
# Row number -1 with index 3367 of 55350 done. 0.0% complete
# Row number -1 with index 3368 of 55350 done. 0.0% complete
# Row number -1 with index 3369 of 55350 done. 0.0% complete
# Row number -1 with index 3370 of 55350 done. 0.0% complete
# Row number -1 with index 3371 of 55350 done. 0.0% complete
# Row number -1 with index 3372 of 55350 done. 0.0% complete
# Row number -1 with index 3373 of 55350 done. 0.0% complete
# Row number -1 with index 3375 of 55350 done. 0.0% complete
# Row number -1 with index 3376 of 55350 done. 0.0% complete
# Row number -1 with index 3377 of 55350 done. 0.0% complete
# Row number -1 with index 3379 of 55350 done. 0.0% complete
# Row number -1 with index 3380 of 55350 done. 0.0% complete
# Row number -1 with index 3383 of 55350 done. 0.0% complete
# Row number -1 with index 3384 of 55350 done. 0.0% complete
# Row number -1 with index 3386 of 55350 done. 0.0% complete
# Row number -1 with index 3533 of 55350 done. 0.0% complete
# Row number -1 with index 3535 of 55350 done. 0.0% complete
# Row number -1 with index 3542 of 55350 done. 0.0% complete
# Row number -1 with index 3543 of 55350 done. 0.0% complete
# Row number -1 with index 3545 of 55350 done. 0.0% complete
# Row number -1 with index 3546 of 55350 done. 0.0% complete
# Row number -1 with index 3549 of 55350 done. 0.0% complete
# Row number -1 with index 3551 of 55350 done. 0.0% complete
# Row number -1 with index 3553 of 55350 done. 0.0% complete
# Row number -1 with index 3556 of 55350 done. 0.0% complete
# Row number -1 with index 3558 of 55350 done. 0.0% complete
# Row number -1 with index 3648 of 55350 done. 0.0% complete
# Row number -1 with index 3649 of 55350 done. 0.0% complete
# Row number -1 with index 3650 of 55350 done. 0.0% complete
# Row number -1 with index 3651 of 55350 done. 0.0% complete
# Row number -1 with index 3653 of 55350 done. 0.0% complete
# Row number -1 with index 3654 of 55350 done. 0.0% complete
# Row number -1 with index 3655 of 55350 done. 0.0% complete
# Row number -1 with index 3658 of 55350 done. 0.0% complete
# Row number -1 with index 3659 of 55350 done. 0.0% complete
# Row number -1 with index 3660 of 55350 done. 0.0% complete
# Row number -1 with index 3661 of 55350 done. 0.0% complete
# Row number -1 with index 3662 of 55350 done. 0.0% complete
# Row number -1 with index 3707 of 55350 done. 0.0% complete
# Row number -1 with index 3820 of 55350 done. 0.0% complete
# Row number -1 with index 3822 of 55350 done. 0.0% complete
# Row number -1 with index 3827 of 55350 done. 0.0% complete
# Row number -1 with index 3828 of 55350 done. 0.0% complete
# Row number -1 with index 3831 of 55350 done. 0.0% complete
# Row number -1 with index 3839 of 55350 done. 0.0% complete
# Row number -1 with index 3840 of 55350 done. 0.0% complete
# Row number -1 with index 3846 of 55350 done. 0.0% complete
# Row number -1 with index 3849 of 55350 done. 0.0% complete
# Row number -1 with index 3851 of 55350 done. 0.0% complete
# Row number -1 with index 3855 of 55350 done. 0.0% complete
# Row number -1 with index 3857 of 55350 done. 0.0% complete
# Row number -1 with index 3858 of 55350 done. 0.0% complete
# Row number -1 with index 3859 of 55350 done. 0.0% complete
# Row number -1 with index 3860 of 55350 done. 0.0% complete
# Row number -1 with index 3861 of 55350 done. 0.0% complete
# Row number -1 with index 3864 of 55350 done. 0.0% complete
# Row number -1 with index 3865 of 55350 done. 0.0% complete
# Row number -1 with index 3866 of 55350 done. 0.0% complete
# Row number -1 with index 3868 of 55350 done. 0.0% complete
# Row number -1 with index 3869 of 55350 done. 0.0% complete
# Row number -1 with index 3872 of 55350 done. 0.0% complete
# Row number -1 with index 3873 of 55350 done. 0.0% complete
# Row number -1 with index 4140 of 55350 done. 0.0% complete
# Row number -1 with index 4143 of 55350 done. 0.0% complete
# Row number -1 with index 4146 of 55350 done. 0.0% complete
# Row number -1 with index 4147 of 55350 done. 0.0% complete
# Row number -1 with index 4148 of 55350 done. 0.0% complete
# Row number -1 with index 4149 of 55350 done. 0.0% complete
# Row number -1 with index 4150 of 55350 done. 0.0% complete
# Row number -1 with index 4152 of 55350 done. 0.0% complete
# Row number -1 with index 4153 of 55350 done. 0.0% complete
# Row number -1 with index 4156 of 55350 done. 0.0% complete
# Row number -1 with index 4157 of 55350 done. 0.0% complete
# Row number -1 with index 4158 of 55350 done. 0.0% complete
# Row number -1 with index 4159 of 55350 done. 0.0% complete
# Row number -1 with index 4160 of 55350 done. 0.0% complete
# Row number -1 with index 4161 of 55350 done. 0.0% complete
# Row number -1 with index 4165 of 55350 done. 0.0% complete
# Row number -1 with index 4167 of 55350 done. 0.0% complete
# Row number -1 with index 4168 of 55350 done. 0.0% complete
# Row number -1 with index 4366 of 55350 done. 0.0% complete
# Row number -1 with index 4374 of 55350 done. 0.0% complete
# Row number -1 with index 4375 of 55350 done. 0.0% complete
# Row number -1 with index 4380 of 55350 done. 0.0% complete
# Row number -1 with index 4381 of 55350 done. 0.0% complete
# Row number -1 with index 4468 of 55350 done. 0.0% complete
# Row number -1 with index 4470 of 55350 done. 0.0% complete
# Row number -1 with index 4471 of 55350 done. 0.0% complete
# Row number -1 with index 4472 of 55350 done. 0.0% complete
# Row number -1 with index 4475 of 55350 done. 0.0% complete
# Row number -1 with index 4476 of 55350 done. 0.0% complete
# Row number -1 with index 4477 of 55350 done. 0.0% complete
# Row number -1 with index 4478 of 55350 done. 0.0% complete
# Row number -1 with index 4482 of 55350 done. 0.0% complete
# Row number -1 with index 4485 of 55350 done. 0.0% complete
# Row number -1 with index 4486 of 55350 done. 0.0% complete
# Row number -1 with index 4487 of 55350 done. 0.0% complete
# Row number -1 with index 4489 of 55350 done. 0.0% complete
# Row number -1 with index 4492 of 55350 done. 0.0% complete
# Row number -1 with index 4495 of 55350 done. 0.0% complete
# Row number -1 with index 4502 of 55350 done. 0.0% complete
# Row number -1 with index 4504 of 55350 done. 0.0% complete
# Row number -1 with index 4505 of 55350 done. 0.0% complete
# Row number -1 with index 4506 of 55350 done. 0.0% complete
# Row number -1 with index 4507 of 55350 done. 0.0% complete
# Row number -1 with index 4508 of 55350 done. 0.0% complete
# Row number -1 with index 4509 of 55350 done. 0.0% complete
# Row number -1 with index 4510 of 55350 done. 0.0% complete
# Row number -1 with index 4511 of 55350 done. 0.0% complete
# Row number -1 with index 4512 of 55350 done. 0.0% complete
# Row number -1 with index 4514 of 55350 done. 0.0% complete
# Row number -1 with index 4516 of 55350 done. 0.0% complete
# Row number -1 with index 4517 of 55350 done. 0.0% complete
# Row number -1 with index 4518 of 55350 done. 0.0% complete
# Row number -1 with index 4520 of 55350 done. 0.0% complete
# Row number -1 with index 4521 of 55350 done. 0.0% complete
# Row number -1 with index 4525 of 55350 done. 0.0% complete
# Row number -1 with index 4619 of 55350 done. 0.0% complete
# Row number -1 with index 4620 of 55350 done. 0.0% complete
# Row number -1 with index 4621 of 55350 done. 0.0% complete
# Row number -1 with index 4622 of 55350 done. 0.0% complete
# Row number -1 with index 4628 of 55350 done. 0.0% complete
# Row number -1 with index 4629 of 55350 done. 0.0% complete
# Row number -1 with index 4634 of 55350 done. 0.0% complete
# Row number -1 with index 4636 of 55350 done. 0.0% complete
# Row number -1 with index 4637 of 55350 done. 0.0% complete
# Row number -1 with index 4639 of 55350 done. 0.0% complete
# Row number -1 with index 4640 of 55350 done. 0.0% complete
# Row number -1 with index 4641 of 55350 done. 0.0% complete
# Row number -1 with index 4670 of 55350 done. 0.0% complete
# Row number -1 with index 4671 of 55350 done. 0.0% complete
# Row number -1 with index 4673 of 55350 done. 0.0% complete
# Row number -1 with index 4674 of 55350 done. 0.0% complete
# Row number -1 with index 4677 of 55350 done. 0.0% complete
# Row number -1 with index 4680 of 55350 done. 0.0% complete
# Row number -1 with index 4681 of 55350 done. 0.0% complete
# Row number -1 with index 4683 of 55350 done. 0.0% complete
# Row number -1 with index 4684 of 55350 done. 0.0% complete
# Row number -1 with index 4686 of 55350 done. 0.0% complete
# Row number -1 with index 4688 of 55350 done. 0.0% complete
# Row number -1 with index 4690 of 55350 done. 0.0% complete
# Row number -1 with index 4691 of 55350 done. 0.0% complete
# Row number -1 with index 4696 of 55350 done. 0.0% complete
# Row number -1 with index 4697 of 55350 done. 0.0% complete
# Row number -1 with index 4730 of 55350 done. 0.0% complete
# Row number -1 with index 4898 of 55350 done. 0.0% complete
# Row number -1 with index 4899 of 55350 done. 0.0% complete
# Row number -1 with index 4900 of 55350 done. 0.0% complete
# Row number -1 with index 4901 of 55350 done. 0.0% complete
# Row number -1 with index 4913 of 55350 done. 0.0% complete
# Row number -1 with index 4918 of 55350 done. 0.0% complete
# Row number -1 with index 4919 of 55350 done. 0.0% complete
# Row number -1 with index 4923 of 55350 done. 0.0% complete
# Row number -1 with index 5008 of 55350 done. 0.0% complete
# Row number -1 with index 5009 of 55350 done. 0.0% complete
# Row number -1 with index 5010 of 55350 done. 0.0% complete
# Row number -1 with index 5011 of 55350 done. 0.0% complete
# Row number -1 with index 5012 of 55350 done. 0.0% complete
# Row number -1 with index 5013 of 55350 done. 0.0% complete
# Row number -1 with index 5014 of 55350 done. 0.0% complete
# Row number -1 with index 5016 of 55350 done. 0.0% complete
# Row number -1 with index 5017 of 55350 done. 0.0% complete
# Row number -1 with index 5018 of 55350 done. 0.0% complete
# Row number -1 with index 5019 of 55350 done. 0.0% complete
# Row number -1 with index 5020 of 55350 done. 0.0% complete
# Row number -1 with index 5021 of 55350 done. 0.0% complete
# Row number -1 with index 5022 of 55350 done. 0.0% complete
# Row number -1 with index 5023 of 55350 done. 0.0% complete
# Row number -1 with index 5024 of 55350 done. 0.0% complete
# Row number -1 with index 5026 of 55350 done. 0.0% complete
# Row number -1 with index 5027 of 55350 done. 0.0% complete
# Row number -1 with index 5028 of 55350 done. 0.0% complete
# Row number -1 with index 5029 of 55350 done. 0.0% complete
# Row number -1 with index 5030 of 55350 done. 0.0% complete
# Row number -1 with index 5038 of 55350 done. 0.0% complete
# Row number -1 with index 5039 of 55350 done. 0.0% complete
# Row number -1 with index 5040 of 55350 done. 0.0% complete
# Row number -1 with index 5041 of 55350 done. 0.0% complete
# Row number -1 with index 5042 of 55350 done. 0.0% complete
# Row number -1 with index 5044 of 55350 done. 0.0% complete
# Row number -1 with index 5046 of 55350 done. 0.0% complete
# Row number -1 with index 5047 of 55350 done. 0.0% complete
# Row number -1 with index 5048 of 55350 done. 0.0% complete
# Row number -1 with index 5049 of 55350 done. 0.0% complete
# Row number -1 with index 5051 of 55350 done. 0.0% complete
# Row number -1 with index 5053 of 55350 done. 0.0% complete
# Row number -1 with index 5056 of 55350 done. 0.0% complete
# Row number -1 with index 5057 of 55350 done. 0.0% complete
# Row number -1 with index 5058 of 55350 done. 0.0% complete
# Row number -1 with index 5059 of 55350 done. 0.0% complete
# Row number -1 with index 5115 of 55350 done. 0.0% complete
# Row number -1 with index 5117 of 55350 done. 0.0% complete
# Row number -1 with index 5118 of 55350 done. 0.0% complete
# Row number -1 with index 5119 of 55350 done. 0.0% complete
# Row number -1 with index 5120 of 55350 done. 0.0% complete
# Row number -1 with index 5121 of 55350 done. 0.0% complete
# Row number -1 with index 5122 of 55350 done. 0.0% complete
# Row number -1 with index 5125 of 55350 done. 0.0% complete
# Row number -1 with index 5127 of 55350 done. 0.0% complete
# Row number -1 with index 5134 of 55350 done. 0.0% complete
# Row number -1 with index 5135 of 55350 done. 0.0% complete
# Row number -1 with index 5136 of 55350 done. 0.0% complete
# Row number -1 with index 5138 of 55350 done. 0.0% complete
# Row number -1 with index 5139 of 55350 done. 0.0% complete
# Row number -1 with index 5142 of 55350 done. 0.0% complete
# Row number -1 with index 5143 of 55350 done. 0.0% complete
# Row number -1 with index 5207 of 55350 done. 0.0% complete
# Row number -1 with index 5209 of 55350 done. 0.0% complete
# Row number -1 with index 5210 of 55350 done. 0.0% complete
# Row number -1 with index 5213 of 55350 done. 0.0% complete
# Row number -1 with index 5215 of 55350 done. 0.0% complete
# Row number -1 with index 5216 of 55350 done. 0.0% complete
# Row number -1 with index 5217 of 55350 done. 0.0% complete
# Row number -1 with index 5218 of 55350 done. 0.0% complete
# Row number -1 with index 5219 of 55350 done. 0.0% complete
# Row number -1 with index 5221 of 55350 done. 0.0% complete
# Row number -1 with index 5222 of 55350 done. 0.0% complete
# Row number -1 with index 5223 of 55350 done. 0.0% complete
# Row number -1 with index 5224 of 55350 done. 0.0% complete
# Row number -1 with index 5227 of 55350 done. 0.0% complete
# Row number -1 with index 5228 of 55350 done. 0.0% complete
# Row number -1 with index 5231 of 55350 done. 0.0% complete
# Row number -1 with index 5233 of 55350 done. 0.0% complete
# Row number -1 with index 5238 of 55350 done. 0.0% complete
# Row number -1 with index 5243 of 55350 done. 0.0% complete
# Row number -1 with index 5244 of 55350 done. 0.0% complete
# Row number -1 with index 5256 of 55350 done. 0.0% complete
# Row number -1 with index 5258 of 55350 done. 0.0% complete
# Row number -1 with index 5494 of 55350 done. 0.0% complete
# Row number -1 with index 5495 of 55350 done. 0.0% complete
# Row number -1 with index 5496 of 55350 done. 0.0% complete
# Row number -1 with index 5500 of 55350 done. 0.0% complete
# Row number -1 with index 5501 of 55350 done. 0.0% complete
# Row number -1 with index 5506 of 55350 done. 0.0% complete
# Row number -1 with index 5508 of 55350 done. 0.0% complete
# Row number -1 with index 5696 of 55350 done. 0.0% complete
# Row number -1 with index 5697 of 55350 done. 0.0% complete
# Row number -1 with index 5698 of 55350 done. 0.0% complete
# Row number -1 with index 5699 of 55350 done. 0.0% complete
# Row number -1 with index 5701 of 55350 done. 0.0% complete
# Row number -1 with index 5705 of 55350 done. 0.0% complete
# Row number -1 with index 5706 of 55350 done. 0.0% complete
# Row number -1 with index 5707 of 55350 done. 0.0% complete
# Row number -1 with index 5711 of 55350 done. 0.0% complete
# Row number -1 with index 5712 of 55350 done. 0.0% complete
# Row number -1 with index 5751 of 55350 done. 0.0% complete
# Row number -1 with index 5752 of 55350 done. 0.0% complete
# Row number -1 with index 5754 of 55350 done. 0.0% complete
# Row number -1 with index 5755 of 55350 done. 0.0% complete
# Row number -1 with index 5756 of 55350 done. 0.0% complete
# Row number -1 with index 5757 of 55350 done. 0.0% complete
# Row number -1 with index 5758 of 55350 done. 0.0% complete
# Row number -1 with index 5759 of 55350 done. 0.0% complete
# Row number -1 with index 5760 of 55350 done. 0.0% complete
# Row number -1 with index 5762 of 55350 done. 0.0% complete
# Row number -1 with index 5763 of 55350 done. 0.0% complete
# Row number -1 with index 5769 of 55350 done. 0.0% complete
# Row number -1 with index 5770 of 55350 done. 0.0% complete
# Row number -1 with index 5771 of 55350 done. 0.0% complete
# Row number -1 with index 5772 of 55350 done. 0.0% complete
# Row number -1 with index 5773 of 55350 done. 0.0% complete
# Row number -1 with index 5777 of 55350 done. 0.0% complete
# Row number -1 with index 5779 of 55350 done. 0.0% complete
# Row number -1 with index 5780 of 55350 done. 0.0% complete
# Row number -1 with index 5912 of 55350 done. 0.0% complete
# Row number -1 with index 5913 of 55350 done. 0.0% complete
# Row number -1 with index 6117 of 55350 done. 0.0% complete
# Row number -1 with index 6118 of 55350 done. 0.0% complete
# Row number -1 with index 6123 of 55350 done. 0.0% complete
# Row number -1 with index 6124 of 55350 done. 0.0% complete
# Row number -1 with index 6125 of 55350 done. 0.0% complete
# Row number -1 with index 6126 of 55350 done. 0.0% complete
# Row number -1 with index 6127 of 55350 done. 0.0% complete
# Row number -1 with index 6128 of 55350 done. 0.0% complete
# Row number -1 with index 6131 of 55350 done. 0.0% complete
# Row number -1 with index 6132 of 55350 done. 0.0% complete
# Row number -1 with index 6135 of 55350 done. 0.0% complete
# Row number -1 with index 6139 of 55350 done. 0.0% complete
# Row number -1 with index 6141 of 55350 done. 0.0% complete
# Row number -1 with index 6142 of 55350 done. 0.0% complete
# Row number -1 with index 6143 of 55350 done. 0.0% complete
# Row number -1 with index 6145 of 55350 done. 0.0% complete
# Row number -1 with index 6146 of 55350 done. 0.0% complete
# Row number -1 with index 6260 of 55350 done. 0.0% complete
# Row number -1 with index 6261 of 55350 done. 0.0% complete
# Row number -1 with index 6262 of 55350 done. 0.0% complete
# Row number -1 with index 6263 of 55350 done. 0.0% complete
# Row number -1 with index 6264 of 55350 done. 0.0% complete
# Row number -1 with index 6265 of 55350 done. 0.0% complete
# Row number -1 with index 6266 of 55350 done. 0.0% complete
# Row number -1 with index 6267 of 55350 done. 0.0% complete
# Row number -1 with index 6268 of 55350 done. 0.0% complete
# Row number -1 with index 6269 of 55350 done. 0.0% complete
# Row number -1 with index 6270 of 55350 done. 0.0% complete
# Row number -1 with index 6271 of 55350 done. 0.0% complete
# Row number -1 with index 6273 of 55350 done. 0.0% complete
# Row number -1 with index 6274 of 55350 done. 0.0% complete
# Row number -1 with index 6275 of 55350 done. 0.0% complete
# Row number -1 with index 6276 of 55350 done. 0.0% complete
# Row number -1 with index 6277 of 55350 done. 0.0% complete
# Row number -1 with index 6278 of 55350 done. 0.0% complete
# Row number -1 with index 6279 of 55350 done. 0.0% complete
# Row number -1 with index 6280 of 55350 done. 0.0% complete
# Row number -1 with index 6281 of 55350 done. 0.0% complete
# Row number -1 with index 6282 of 55350 done. 0.0% complete
# Row number -1 with index 6283 of 55350 done. 0.0% complete
# Row number -1 with index 6284 of 55350 done. 0.0% complete
# Row number -1 with index 6285 of 55350 done. 0.0% complete
# Row number -1 with index 6318 of 55350 done. 0.0% complete
# Row number -1 with index 6319 of 55350 done. 0.0% complete
# Row number -1 with index 6322 of 55350 done. 0.0% complete
# Row number -1 with index 6326 of 55350 done. 0.0% complete
# Row number -1 with index 6339 of 55350 done. 0.0% complete
# Row number -1 with index 6340 of 55350 done. 0.0% complete
# Row number -1 with index 6341 of 55350 done. 0.0% complete
# Row number -1 with index 6342 of 55350 done. 0.0% complete
# Row number -1 with index 6344 of 55350 done. 0.0% complete
# Row number -1 with index 6345 of 55350 done. 0.0% complete
# Row number -1 with index 6346 of 55350 done. 0.0% complete
# Row number -1 with index 6349 of 55350 done. 0.0% complete
# Row number -1 with index 6350 of 55350 done. 0.0% complete
# Row number -1 with index 6352 of 55350 done. 0.0% complete
# Row number -1 with index 6354 of 55350 done. 0.0% complete
# Row number -1 with index 6358 of 55350 done. 0.0% complete
# Row number -1 with index 6361 of 55350 done. 0.0% complete
# Row number -1 with index 6365 of 55350 done. 0.0% complete
# Row number -1 with index 6366 of 55350 done. 0.0% complete
# Row number -1 with index 6370 of 55350 done. 0.0% complete
# Row number -1 with index 6431 of 55350 done. 0.0% complete
# Row number -1 with index 6432 of 55350 done. 0.0% complete
# Row number -1 with index 6448 of 55350 done. 0.0% complete
# Row number -1 with index 6451 of 55350 done. 0.0% complete
# Row number -1 with index 6454 of 55350 done. 0.0% complete
# Row number -1 with index 6455 of 55350 done. 0.0% complete
# Row number -1 with index 6456 of 55350 done. 0.0% complete
# Row number -1 with index 6457 of 55350 done. 0.0% complete
# Row number -1 with index 6461 of 55350 done. 0.0% complete
# Row number -1 with index 6462 of 55350 done. 0.0% complete
# Row number -1 with index 6467 of 55350 done. 0.0% complete
# Row number -1 with index 6471 of 55350 done. 0.0% complete
# Row number -1 with index 6473 of 55350 done. 0.0% complete
# Row number -1 with index 6474 of 55350 done. 0.0% complete
# Row number -1 with index 6475 of 55350 done. 0.0% complete
# Row number -1 with index 6476 of 55350 done. 0.0% complete
# Row number -1 with index 6479 of 55350 done. 0.0% complete
# Row number -1 with index 6570 of 55350 done. 0.0% complete
# Row number -1 with index 6574 of 55350 done. 0.0% complete
# Row number -1 with index 6578 of 55350 done. 0.0% complete
# Row number -1 with index 6579 of 55350 done. 0.0% complete
# Row number -1 with index 6580 of 55350 done. 0.0% complete
# Row number -1 with index 6581 of 55350 done. 0.0% complete
# Row number -1 with index 6583 of 55350 done. 0.0% complete
# Row number -1 with index 6584 of 55350 done. 0.0% complete
# Row number -1 with index 6587 of 55350 done. 0.0% complete
# Row number -1 with index 6588 of 55350 done. 0.0% complete
# Row number -1 with index 6668 of 55350 done. 0.0% complete
# Row number -1 with index 6669 of 55350 done. 0.0% complete
# Row number -1 with index 6670 of 55350 done. 0.0% complete
# Row number -1 with index 6671 of 55350 done. 0.0% complete
# Row number -1 with index 6672 of 55350 done. 0.0% complete
# Row number -1 with index 6674 of 55350 done. 0.0% complete
# Row number -1 with index 6675 of 55350 done. 0.0% complete
# Row number -1 with index 6676 of 55350 done. 0.0% complete
# Row number -1 with index 6680 of 55350 done. 0.0% complete
# Row number -1 with index 6681 of 55350 done. 0.0% complete
# Row number -1 with index 6682 of 55350 done. 0.0% complete
# Row number -1 with index 6684 of 55350 done. 0.0% complete
# Row number -1 with index 6686 of 55350 done. 0.0% complete
# Row number -1 with index 6687 of 55350 done. 0.0% complete
# Row number -1 with index 6690 of 55350 done. 0.0% complete
# Row number -1 with index 6693 of 55350 done. 0.0% complete
# Row number -1 with index 6701 of 55350 done. 0.0% complete
# Row number -1 with index 6702 of 55350 done. 0.0% complete
# Row number -1 with index 6703 of 55350 done. 0.0% complete
# Row number -1 with index 6704 of 55350 done. 0.0% complete
# Row number -1 with index 6706 of 55350 done. 0.0% complete
# Row number -1 with index 6712 of 55350 done. 0.0% complete
# Row number -1 with index 6717 of 55350 done. 0.0% complete
# Row number -1 with index 6718 of 55350 done. 0.0% complete
# Row number -1 with index 6719 of 55350 done. 0.0% complete
# Row number -1 with index 6720 of 55350 done. 0.0% complete
# Row number -1 with index 6721 of 55350 done. 0.0% complete
# Row number -1 with index 6722 of 55350 done. 0.0% complete
# Row number -1 with index 6723 of 55350 done. 0.0% complete
# Row number -1 with index 6728 of 55350 done. 0.0% complete
# Row number -1 with index 6729 of 55350 done. 0.0% complete
# Row number -1 with index 6732 of 55350 done. 0.0% complete
# Row number -1 with index 6737 of 55350 done. 0.0% complete
# Row number -1 with index 6738 of 55350 done. 0.0% complete
# Row number -1 with index 6739 of 55350 done. 0.0% complete
# Row number -1 with index 6740 of 55350 done. 0.0% complete
# Row number -1 with index 6742 of 55350 done. 0.0% complete
# Row number -1 with index 6840 of 55350 done. 0.0% complete
# Row number -1 with index 6845 of 55350 done. 0.0% complete
# Row number -1 with index 6852 of 55350 done. 0.0% complete
# Row number -1 with index 6913 of 55350 done. 0.0% complete
# Row number -1 with index 6915 of 55350 done. 0.0% complete
# Row number -1 with index 6918 of 55350 done. 0.0% complete
# Row number -1 with index 6919 of 55350 done. 0.0% complete
# Row number -1 with index 6922 of 55350 done. 0.0% complete
# Row number -1 with index 6923 of 55350 done. 0.0% complete
# Row number -1 with index 6924 of 55350 done. 0.0% complete
# Row number -1 with index 6925 of 55350 done. 0.0% complete
# Row number -1 with index 6926 of 55350 done. 0.0% complete
# Row number -1 with index 6930 of 55350 done. 0.0% complete
# Row number -1 with index 6934 of 55350 done. 0.0% complete
# Row number -1 with index 6935 of 55350 done. 0.0% complete
# Row number -1 with index 6937 of 55350 done. 0.0% complete
# Row number -1 with index 6939 of 55350 done. 0.0% complete
# Row number -1 with index 7022 of 55350 done. 0.0% complete
# Row number -1 with index 7026 of 55350 done. 0.0% complete
# Row number -1 with index 7027 of 55350 done. 0.0% complete
# Row number -1 with index 7029 of 55350 done. 0.0% complete
# Row number -1 with index 7030 of 55350 done. 0.0% complete
# Row number -1 with index 7031 of 55350 done. 0.0% complete
# Row number -1 with index 7033 of 55350 done. 0.0% complete
# Row number -1 with index 7037 of 55350 done. 0.0% complete
# Row number -1 with index 7038 of 55350 done. 0.0% complete
# Row number -1 with index 7039 of 55350 done. 0.0% complete
# Row number -1 with index 7040 of 55350 done. 0.0% complete
# Row number -1 with index 7041 of 55350 done. 0.0% complete
# Row number -1 with index 7097 of 55350 done. 0.0% complete
# Row number -1 with index 7336 of 55350 done. 0.0% complete
# Row number -1 with index 7369 of 55350 done. 0.0% complete
# Row number -1 with index 7371 of 55350 done. 0.0% complete
# Row number -1 with index 7372 of 55350 done. 0.0% complete
# Row number -1 with index 7373 of 55350 done. 0.0% complete
# Row number -1 with index 7375 of 55350 done. 0.0% complete
# Row number -1 with index 7376 of 55350 done. 0.0% complete
# Row number -1 with index 7377 of 55350 done. 0.0% complete
# Row number -1 with index 7381 of 55350 done. 0.0% complete
# Row number -1 with index 7382 of 55350 done. 0.0% complete
# Row number -1 with index 7383 of 55350 done. 0.0% complete
# Row number -1 with index 7384 of 55350 done. 0.0% complete
# Row number -1 with index 7386 of 55350 done. 0.0% complete
# Row number -1 with index 7389 of 55350 done. 0.0% complete
# Row number -1 with index 7392 of 55350 done. 0.0% complete
# Row number -1 with index 7393 of 55350 done. 0.0% complete
# Row number -1 with index 7394 of 55350 done. 0.0% complete
# Row number -1 with index 7501 of 55350 done. 0.0% complete
# Row number -1 with index 7502 of 55350 done. 0.0% complete
# Row number -1 with index 7503 of 55350 done. 0.0% complete
# Row number -1 with index 7505 of 55350 done. 0.0% complete
# Row number -1 with index 7506 of 55350 done. 0.0% complete
# Row number -1 with index 7514 of 55350 done. 0.0% complete
# Row number -1 with index 7515 of 55350 done. 0.0% complete
# Row number -1 with index 7516 of 55350 done. 0.0% complete
# Row number -1 with index 7523 of 55350 done. 0.0% complete
# Row number -1 with index 7525 of 55350 done. 0.0% complete
# Row number -1 with index 7526 of 55350 done. 0.0% complete
# Row number -1 with index 7527 of 55350 done. 0.0% complete
# Row number -1 with index 7528 of 55350 done. 0.0% complete
# Row number -1 with index 7529 of 55350 done. 0.0% complete
# Row number -1 with index 7530 of 55350 done. 0.0% complete
# Row number -1 with index 7548 of 55350 done. 0.0% complete
# Row number -1 with index 7550 of 55350 done. 0.0% complete
# Row number -1 with index 7751 of 55350 done. 0.0% complete
# Row number -1 with index 7752 of 55350 done. 0.0% complete
# Row number -1 with index 7755 of 55350 done. 0.0% complete
# Row number -1 with index 7756 of 55350 done. 0.0% complete
# Row number -1 with index 7757 of 55350 done. 0.0% complete
# Row number -1 with index 7759 of 55350 done. 0.0% complete
# Row number -1 with index 7760 of 55350 done. 0.0% complete
# Row number -1 with index 7761 of 55350 done. 0.0% complete
# Row number -1 with index 7763 of 55350 done. 0.0% complete
# Row number -1 with index 7764 of 55350 done. 0.0% complete
# Row number -1 with index 7765 of 55350 done. 0.0% complete
# Row number -1 with index 7767 of 55350 done. 0.0% complete
# Row number -1 with index 7769 of 55350 done. 0.0% complete
# Row number -1 with index 7777 of 55350 done. 0.0% complete
# Row number -1 with index 7778 of 55350 done. 0.0% complete
# Row number -1 with index 7783 of 55350 done. 0.0% complete
# Row number -1 with index 7786 of 55350 done. 0.0% complete
# Row number -1 with index 7789 of 55350 done. 0.0% complete
# Row number -1 with index 7796 of 55350 done. 0.0% complete
# Row number -1 with index 7797 of 55350 done. 0.0% complete
# Row number -1 with index 7802 of 55350 done. 0.0% complete
# Row number -1 with index 7803 of 55350 done. 0.0% complete
# Row number -1 with index 7850 of 55350 done. 0.0% complete
# Row number -1 with index 7853 of 55350 done. 0.0% complete
# Row number -1 with index 7854 of 55350 done. 0.0% complete
# Row number -1 with index 7857 of 55350 done. 0.0% complete
# Row number -1 with index 7860 of 55350 done. 0.0% complete
# Row number -1 with index 7862 of 55350 done. 0.0% complete
# Row number -1 with index 7863 of 55350 done. 0.0% complete
# Row number -1 with index 7868 of 55350 done. 0.0% complete
# Row number -1 with index 7870 of 55350 done. 0.0% complete
# Row number -1 with index 7872 of 55350 done. 0.0% complete
# Row number -1 with index 7873 of 55350 done. 0.0% complete
# Row number -1 with index 7874 of 55350 done. 0.0% complete
# Row number -1 with index 7876 of 55350 done. 0.0% complete
# Row number -1 with index 7879 of 55350 done. 0.0% complete
# Row number -1 with index 8065 of 55350 done. 0.0% complete
# Row number -1 with index 8066 of 55350 done. 0.0% complete
# Row number -1 with index 8067 of 55350 done. 0.0% complete
# Row number -1 with index 8069 of 55350 done. 0.0% complete
# Row number -1 with index 8071 of 55350 done. 0.0% complete
# Row number -1 with index 8073 of 55350 done. 0.0% complete
# Row number -1 with index 8080 of 55350 done. 0.0% complete
# Row number -1 with index 8081 of 55350 done. 0.0% complete
# Row number -1 with index 8082 of 55350 done. 0.0% complete
# Row number -1 with index 8083 of 55350 done. 0.0% complete
# Row number -1 with index 8086 of 55350 done. 0.0% complete
# Row number -1 with index 8087 of 55350 done. 0.0% complete
# Row number -1 with index 8090 of 55350 done. 0.0% complete
# Row number -1 with index 8091 of 55350 done. 0.0% complete
# Row number -1 with index 8093 of 55350 done. 0.0% complete
# Row number -1 with index 8094 of 55350 done. 0.0% complete
# Row number -1 with index 8095 of 55350 done. 0.0% complete
# Row number -1 with index 8096 of 55350 done. 0.0% complete
# Row number -1 with index 8101 of 55350 done. 0.0% complete
# Row number -1 with index 8105 of 55350 done. 0.0% complete
# Row number -1 with index 8106 of 55350 done. 0.0% complete
# Row number -1 with index 8108 of 55350 done. 0.0% complete
# Row number -1 with index 8111 of 55350 done. 0.0% complete
# Row number -1 with index 8112 of 55350 done. 0.0% complete
# Row number -1 with index 8115 of 55350 done. 0.0% complete
# Row number -1 with index 8116 of 55350 done. 0.0% complete
# Row number -1 with index 8117 of 55350 done. 0.0% complete
# Row number -1 with index 8118 of 55350 done. 0.0% complete
# Row number -1 with index 8123 of 55350 done. 0.0% complete
# Row number -1 with index 8190 of 55350 done. 0.0% complete
# Row number -1 with index 8191 of 55350 done. 0.0% complete
# Row number -1 with index 8192 of 55350 done. 0.0% complete
# Row number -1 with index 8199 of 55350 done. 0.0% complete
# Row number -1 with index 8200 of 55350 done. 0.0% complete
# Row number -1 with index 8201 of 55350 done. 0.0% complete
# Row number -1 with index 8208 of 55350 done. 0.0% complete
# Row number -1 with index 8210 of 55350 done. 0.0% complete
# Row number -1 with index 8211 of 55350 done. 0.0% complete
# Row number -1 with index 8212 of 55350 done. 0.0% complete
# Row number -1 with index 8219 of 55350 done. 0.0% complete
# Row number -1 with index 8220 of 55350 done. 0.0% complete
# Row number -1 with index 8222 of 55350 done. 0.0% complete
# Row number -1 with index 8224 of 55350 done. 0.0% complete
# Row number -1 with index 8225 of 55350 done. 0.0% complete
# Row number -1 with index 8228 of 55350 done. 0.0% complete
# Row number -1 with index 8229 of 55350 done. 0.0% complete
# Row number -1 with index 8232 of 55350 done. 0.0% complete
# Row number -1 with index 8235 of 55350 done. 0.0% complete
# Row number -1 with index 8288 of 55350 done. 0.0% complete
# Row number -1 with index 8289 of 55350 done. 0.0% complete
# Row number -1 with index 8294 of 55350 done. 0.0% complete
# Row number -1 with index 8295 of 55350 done. 0.0% complete
# Row number -1 with index 8297 of 55350 done. 0.0% complete
# Row number -1 with index 8298 of 55350 done. 0.0% complete
# Row number -1 with index 8299 of 55350 done. 0.0% complete
# ...
# Row number -1 with index 26767 of 55350 done. 0.0% complete
# Row number -1 with index 26768 of 55350 done. 0.0% complete
# Row number -1 with index 26769 of 55350 done. 0.0% complete
# Row number -1 with index 26770 of 55350 done. 0.0% complete
# Row number -1 with index 26772 of 55350 done. 0.0% complete
# Row number -1 with index 26774 of 55350 done. 0.0% complete
# Row number -1 with index 26775 of 55350 done. 0.0% complete
# Row number -1 with index 26777 of 55350 done. 0.0% complete
# Row number -1 with index 26779 of 55350 done. 0.0% complete
# Row number -1 with index 26781 of 55350 done. 0.0% complete
# Row number -1 with index 26782 of 55350 done. 0.0% complete
# Row number -1 with index 26783 of 55350 done. 0.0% complete
# Row number -1 with index 26784 of 55350 done. 0.0% complete
# Row number -1 with index 26786 of 55350 done. 0.0% complete
# Row number -1 with index 26787 of 55350 done. 0.0% complete
# Row number -1 with index 26788 of 55350 done. 0.0% complete
# Row number -1 with index 26891 of 55350 done. 0.0% complete
# Row number -1 with index 26892 of 55350 done. 0.0% complete
# Row number -1 with index 26897 of 55350 done. 0.0% complete
# Row number -1 with index 26898 of 55350 done. 0.0% complete
# Row number -1 with index 26899 of 55350 done. 0.0% complete
# Row number -1 with index 26901 of 55350 done. 0.0% complete
# Row number -1 with index 26904 of 55350 done. 0.0% complete
# Row number -1 with index 26909 of 55350 done. 0.0% complete
# Row number -1 with index 27047 of 55350 done. 0.0% complete
# Row number -1 with index 27048 of 55350 done. 0.0% complete
# Row number -1 with index 27049 of 55350 done. 0.0% complete
# Row number -1 with index 27050 of 55350 done. 0.0% complete
# Row number -1 with index 27052 of 55350 done. 0.0% complete
# Row number -1 with index 27053 of 55350 done. 0.0% complete
# Row number -1 with index 27064 of 55350 done. 0.0% complete
# Row number -1 with index 27065 of 55350 done. 0.0% complete
# Row number -1 with index 27066 of 55350 done. 0.0% complete
# Row number -1 with index 27067 of 55350 done. 0.0% complete
# Row number -1 with index 27068 of 55350 done. 0.0% complete
# Row number -1 with index 27070 of 55350 done. 0.0% complete
# Row number -1 with index 27071 of 55350 done. 0.0% complete
# Row number -1 with index 27076 of 55350 done. 0.0% complete
# Row number -1 with index 27262 of 55350 done. 0.0% complete
# Row number -1 with index 27266 of 55350 done. 0.0% complete
# Row number -1 with index 27270 of 55350 done. 0.0% complete
# Row number -1 with index 27271 of 55350 done. 0.0% complete
# Row number -1 with index 27273 of 55350 done. 0.0% complete
# Row number -1 with index 27274 of 55350 done. 0.0% complete
# Row number -1 with index 27278 of 55350 done. 0.0% complete
# Row number -1 with index 27336 of 55350 done. 0.0% complete
# Row number -1 with index 27339 of 55350 done. 0.0% complete
# Row number -1 with index 27345 of 55350 done. 0.0% complete
# Row number -1 with index 27348 of 55350 done. 0.0% complete
# Row number -1 with index 27351 of 55350 done. 0.0% complete
# Row number -1 with index 27352 of 55350 done. 0.0% complete
# Row number -1 with index 27354 of 55350 done. 0.0% complete
# Row number -1 with index 27355 of 55350 done. 0.0% complete
# Row number -1 with index 27357 of 55350 done. 0.0% complete
# Row number -1 with index 27358 of 55350 done. 0.0% complete
# Row number -1 with index 27360 of 55350 done. 0.0% complete
# Row number -1 with index 27409 of 55350 done. 0.0% complete
# Row number -1 with index 27410 of 55350 done. 0.0% complete
# Row number -1 with index 27412 of 55350 done. 0.0% complete
# Row number -1 with index 27415 of 55350 done. 0.0% complete
# Row number -1 with index 27416 of 55350 done. 0.0% complete
# Row number -1 with index 27417 of 55350 done. 0.0% complete
# Row number -1 with index 27419 of 55350 done. 0.0% complete
# Row number -1 with index 27420 of 55350 done. 0.0% complete
# Row number -1 with index 27430 of 55350 done. 0.0% complete
# Row number -1 with index 27552 of 55350 done. 0.0% complete
# Row number -1 with index 27555 of 55350 done. 0.0% complete
# Row number -1 with index 27556 of 55350 done. 0.0% complete
# Row number -1 with index 27561 of 55350 done. 0.0% complete
# Row number -1 with index 27562 of 55350 done. 0.0% complete
# Row number -1 with index 27566 of 55350 done. 0.0% complete
# Row number -1 with index 27568 of 55350 done. 0.0% complete
# Row number -1 with index 27569 of 55350 done. 0.0% complete
# Row number -1 with index 27572 of 55350 done. 0.0% complete
# Row number -1 with index 27573 of 55350 done. 0.0% complete
# Row number -1 with index 27574 of 55350 done. 0.0% complete
# Row number -1 with index 27577 of 55350 done. 0.0% complete
# Row number -1 with index 27578 of 55350 done. 0.0% complete
# Row number -1 with index 27598 of 55350 done. 0.0% complete
# Row number -1 with index 27603 of 55350 done. 0.0% complete
# Row number -1 with index 27606 of 55350 done. 0.0% complete
# Row number -1 with index 27790 of 55350 done. 0.0% complete
# Row number -1 with index 27791 of 55350 done. 0.0% complete
# Row number -1 with index 27793 of 55350 done. 0.0% complete
# Row number -1 with index 27794 of 55350 done. 0.0% complete
# Row number -1 with index 27795 of 55350 done. 0.0% complete
# Row number -1 with index 27796 of 55350 done. 0.0% complete
# Row number -1 with index 27797 of 55350 done. 0.0% complete
# Row number -1 with index 27798 of 55350 done. 0.0% complete
# Row number -1 with index 27799 of 55350 done. 0.0% complete
# Row number -1 with index 27800 of 55350 done. 0.0% complete
# Row number -1 with index 27804 of 55350 done. 0.0% complete
# Row number -1 with index 27805 of 55350 done. 0.0% complete
# Row number -1 with index 27806 of 55350 done. 0.0% complete
# Row number -1 with index 27809 of 55350 done. 0.0% complete
# Row number -1 with index 27810 of 55350 done. 0.0% complete
# Row number -1 with index 27811 of 55350 done. 0.0% complete
# Row number -1 with index 27812 of 55350 done. 0.0% complete
# Row number -1 with index 27813 of 55350 done. 0.0% complete
# Row number -1 with index 27814 of 55350 done. 0.0% complete
# Row number -1 with index 27815 of 55350 done. 0.0% complete
# Row number -1 with index 27847 of 55350 done. 0.0% complete
# Row number -1 with index 27849 of 55350 done. 0.0% complete
# Row number -1 with index 27850 of 55350 done. 0.0% complete
# Row number -1 with index 27851 of 55350 done. 0.0% complete
# Row number -1 with index 27852 of 55350 done. 0.0% complete
# Row number -1 with index 27853 of 55350 done. 0.0% complete
# Row number -1 with index 27856 of 55350 done. 0.0% complete
# Row number -1 with index 27857 of 55350 done. 0.0% complete
# Row number -1 with index 27858 of 55350 done. 0.0% complete
# Row number -1 with index 27860 of 55350 done. 0.0% complete
# Row number -1 with index 27865 of 55350 done. 0.0% complete
# Row number -1 with index 27866 of 55350 done. 0.0% complete
# Row number -1 with index 27867 of 55350 done. 0.0% complete
# Row number -1 with index 27868 of 55350 done. 0.0% complete
# Row number -1 with index 27871 of 55350 done. 0.0% complete
# Row number -1 with index 27873 of 55350 done. 0.0% complete
# Row number -1 with index 27874 of 55350 done. 0.0% complete
# Row number -1 with index 27875 of 55350 done. 0.0% complete
# Row number -1 with index 27953 of 55350 done. 0.0% complete
# Row number -1 with index 27954 of 55350 done. 0.0% complete
# Row number -1 with index 27955 of 55350 done. 0.0% complete
# Row number -1 with index 27956 of 55350 done. 0.0% complete
# Row number -1 with index 27957 of 55350 done. 0.0% complete
# Row number -1 with index 27958 of 55350 done. 0.0% complete
# Row number -1 with index 27959 of 55350 done. 0.0% complete
# Row number -1 with index 27960 of 55350 done. 0.0% complete
# Row number -1 with index 27961 of 55350 done. 0.0% complete
# Row number -1 with index 27962 of 55350 done. 0.0% complete
# Row number -1 with index 27963 of 55350 done. 0.0% complete
# Row number -1 with index 27964 of 55350 done. 0.0% complete
# Row number -1 with index 27966 of 55350 done. 0.0% complete
# Row number -1 with index 27967 of 55350 done. 0.0% complete
# Row number -1 with index 27968 of 55350 done. 0.0% complete
# Row number -1 with index 27971 of 55350 done. 0.0% complete
# Row number -1 with index 27974 of 55350 done. 0.0% complete
# Row number -1 with index 27975 of 55350 done. 0.0% complete
# Row number -1 with index 27976 of 55350 done. 0.0% complete
# Row number -1 with index 27977 of 55350 done. 0.0% complete
# Row number -1 with index 27979 of 55350 done. 0.0% complete
# Row number -1 with index 27980 of 55350 done. 0.0% complete
# Row number -1 with index 27981 of 55350 done. 0.0% complete
# Row number -1 with index 28093 of 55350 done. 0.0% complete
# Row number -1 with index 28094 of 55350 done. 0.0% complete
# Row number -1 with index 28100 of 55350 done. 0.0% complete
# Row number -1 with index 28101 of 55350 done. 0.0% complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [51], line 12
#       8 for index, row in location_df.iterrows():
#       9   params = {'address': row['address'],
#      10             'key': api_key}
# ---> 12   result = get_json(row['address'])
#      14   if result['status'] != 'OK':
#      15     print(f"Error on row number {counter} with index {index}. \nError response: {result['status']}")
#
# Cell In [49], line 8, in get_json(x)
#       4 ''' Gets the geocoding json for a specified address string'''
#       5 params = {'address': x,
#       6           'key': api_key}
# ----> 8 result = requests.get(geocoding_url, params = params).json()
#      10 return result
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Putting these bad boys into a dataframe

lats = [row[0]['lat'] for row in output_list]
lons = [row[0]['lng'] for row in output_list]
wineries = [row[1] for row in output_list]

latlon_df = pd.DataFrame({'winery': wineries,
                          'lat': lats,
                          'lon': lons})

# %%
# Merging onto our original dataframe by winery

df = df.merge(latlon_df, how = 'left', on = 'winery')
